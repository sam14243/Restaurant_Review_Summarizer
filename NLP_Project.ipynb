# %%
import re
import string
import pandas as pd
from bs4 import BeautifulSoup
import numpy as np

import nltk
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

from gensim.models import Word2Vec, KeyedVectors
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.utils import simple_preprocess

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from keras.layers import LSTM, Bidirectional, Dropout, Dense, Embedding, Conv1D, MaxPooling1D, GlobalMaxPooling1D
from keras import Model, Input
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %% [markdown]
# ## Pre-processing

# %%
data = pd.read_csv("Restaurant reviews.csv")

# %%
data = data.drop(['Restaurant', 'Reviewer','Metadata', 'Time', 'Pictures', '7514'], axis=1)

# %%
data = data.dropna()

# %%
data = data[data.Rating != 'Like']

# %%
data['Rating'] = data['Rating'].astype('float')

# %%
url_pattern = re.compile(r'https?://\S+|www\.\S+')
punctuation_pattern = re.compile('[%s]' % re.escape(string.punctuation))
newline_pattern = re.compile('\n')
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
tag_dict = {'J': wordnet.ADJ,'N': wordnet.NOUN,'V': wordnet.VERB,'R': wordnet.ADV}

# %%
def preprocess_text(text):
    text = str(text).lower()
    clean_text = re.sub('https?://\S+|www\.\S+', '', text) #URLs
    clean_text = re.sub('[%s]' % re.escape(string.punctuation), '', clean_text) #Punctuations
    clean_text = re.sub('\n', '', clean_text) #Backslash n
    clean_text = [word for word in clean_text.split(' ') if word not in stop_words] #Remove stopwords
    # clean_text =" ".join(clean_text)
    # tokens = clean_text.split()
    pos_tags = nltk.pos_tag(clean_text)
    wordnet_tags = [(token, tag_dict.get(tag[0].upper(), wordnet.NOUN)) for token, tag in pos_tags]
    tokens = [lemmatizer.lemmatize(token, tag) for token, tag in wordnet_tags] #Lemmatize
    return " ".join(tokens)

# %%
data['Clean_Review'] = data['Review'].apply(preprocess_text)

# %%
data
# Out:
#                                                  Review  Rating  \
# 0     The ambience was good, food was quite good . h...     5.0
# 1     Ambience is too good for a pleasant evening. S...     5.0
# 2     A must try.. great food great ambience. Thnx f...     5.0
# 3     Soumen das and Arun was a great guy. Only beca...     5.0
# 4     Food is good.we ordered Kodi drumsticks and ba...     5.0
# ...                                                 ...     ...
# 9995  Madhumathi Mahajan Well to start with nice cou...     3.0
# 9996  This place has never disappointed us.. The foo...     4.5
# 9997  Bad rating is mainly because of "Chicken Bone ...     1.5
# 9998  I personally love and prefer Chinese Food. Had...     4.0
# 9999  Checked in here to try some delicious chinese ...     3.5
#
#                                            Clean_Review
# 0     ambience good food quite good  saturday lunch ...
# 1     ambience good pleasant even service prompt foo...
# 2     must try great food great ambience thnx servic...
# 3     soumen das arun great guy behavior sincerety g...
# 4     food goodwe order kodi drumstick basket mutton...
# ...                                                 ...
# 9995  madhumathi mahajan well start nice courteous s...
# 9996  place never disappoint u food courteous staff ...
# 9997  bad rating mainly chicken bone find veg food a...
# 9998  personally love prefer chinese food couple tim...
# 9999  check try delicious chinese food see nonveg lu...
#
# [9954 rows x 3 columns]

# %%
data['Sentiment'] = (data['Rating'] > 3).astype('int')

# %%
data.drop(['Review', 'Rating'], axis=1, inplace=True)

# %%
data.dropna(inplace=True)
data.reset_index(drop=True, inplace=True)

# %%
data['tokens'] = data['Clean_Review'].map(lambda x: word_tokenize(x))

# %%
data.to_csv('Cleaned_dataset.csv', index=False)

# %%
pdata = data[data['Sentiment'] == 1]
ndata = data[data['Sentiment'] == 0]

# %%
import collections
all_words = []


for line in list(pdata['Clean_Review']):
  words = line.split()
  for word in words:
    all_words.append(word.lower())
    
collections.Counter(all_words).most_common(15)
# Out:
# [('good', 4922),
#  ('place', 4254),
#  ('food', 3704),
#  ('chicken', 1804),
#  ('service', 1730),
#  ('taste', 1662),
#  ('great', 1488),
#  ('order', 1441),
#  ('try', 1424),
#  ('visit', 1279),
#  ('one', 1265),
#  ('best', 1241),
#  ('time', 1229),
#  ('really', 1220),
#  ('ambience', 1195)]

# %%
import collections
all_words = []


for line in list(ndata['Clean_Review']):
  words = line.split()
  for word in words:
    all_words.append(word.lower())
    
collections.Counter(all_words).most_common(15)
# Out:
# [('food', 2088),
#  ('order', 1906),
#  ('good', 1790),
#  ('place', 1557),
#  ('chicken', 1093),
#  ('taste', 1084),
#  ('bad', 1059),
#  ('service', 898),
#  ('go', 745),
#  ('like', 711),
#  ('time', 699),
#  ('get', 660),
#  ('one', 649),
#  ('restaurant', 626),
#  ('even', 585)]

# %% [markdown]
# ## Training

# %%
data = pd.read_csv("Cleaned_dataset.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9940 entries, 0 to 9939
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Review        9940 non-null   object
#  1   Rating        9940 non-null   float64
#  2   Clean_Review  9940 non-null   object
#  3   Sentiment     9940 non-null   int64
#  4   tokens        9940 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 388.4+ KB

# %%
# sentence_bow = vectorizer.fit_transform(data['Clean_Review'])
x_train, x_test, y_train, y_test = train_test_split(data['Clean_Review'], data['Sentiment'], test_size=0.2, random_state=42)

# %%
reviews = data['Clean_Review']
reviews_list = []
for i in range(len(reviews)):
    reviews_list.append(reviews[i])

sentiment = data['Sentiment']
y = []
for i in range(len(sentiment)):
  y.append(sentiment[i])

# %%
reviews_list
# Out:
# ['ambience good food quite good  saturday lunch  cost effective good place sate brunch one also chill friend parentswaiter soumen das really courteous helpful',
#  'ambience good pleasant even service prompt food good good experience soumen das  kudos service',
#  'must try great food great ambience thnx service pradeep subroto personal recommendation penne alfredo pasta  also music background amazing',
#  'soumen das arun great guy behavior sincerety good food course would like visit place',
#  'food goodwe order kodi drumstick basket mutton biryani good thanks pradeep serve well enjoy ambience also good',
#  'ambiance good service good food apradeecp subro best servicefood good papiya good hostess ur caption good 4star restaurant',
#  'nice place ambience different food order tasty service also gud worth visit reasonable well really must visit place',
#  'well read many review finally visit placeambience good come food crispy corn nice tawa fish ok basket biryani disappoint u biryani ok flattering claim staff polite prompt especially pradeep suman',
#  'excellent food  specially like spicy food  courteous staff  shubro pradeep papiya give excellent service corporate team dinner  overall great team dinner party',
#  'come birthday treat close friend perfect place treat like hospitable cooperative staff food delicious ambience really good music light chili honey lotus stem must try special mention papiya take good care u',
#  'service great food awesome service staff manab papiya courteous attentive would like come frequently place',
#  'good ambience amaze food good service friendly staff  pradeep papiya shuvro  definitely visit loved design menu card',
#  'food good soup expect starter order honey chilli lotus stem must try vegan ppl service great frequent visit papiya know experience also food really impressive',
#  'food good telangana kodiak fry must trymutton biriyani goodpapiya help choose best dish attend wellmust visit',
#  'order corn cheese ball manchow soup paneer shashlik sizzler sizzler stale paneer smell waiter impolite even accept mistake never go',
#  'food ambience fantastic waiter manav maji really quick service cheese ball must try starter scrumptious',
#  'come lunch food good tasty try buffet item veg nonveg tastythe ambience service also good staff courteousshubhamtraveltaleswordpresscom',
#  'best thing place food favorite go dish definitely alfredo pasta although item good well service behavior staff topnotch attend mr soumen das extremely polite definitely visit soon',
#  'polite friendly staff nice ambience good spread menu drink awesome service good manav look forward see',
#  'food really good vegetarian item include paneer mushroom kofta additionally service papiya  shuvro really good',
#  'beautiful cozy classy time place truly recommend special day 15 percent corporate discount treat cotorie well without burn hole ur pocket also interior do well love vibe menu honey chilli lotus stem basket biryani sizzle brownie favourite also love tomato basil shorba different creamy standard restaurant im definitely make visit beyond flavour special mention papiya hostess even excellent service ',
#  'im much impressed quality food service specially mr ahmed thank politeness readiness food say beyond flavour loved place must visit great ambience',
#  'food indeed beyond falvours ahmed serve u well hop meet next time soon great ambience amazing song background add innumerous flavour delicious food',
#  'starter good service also good ahmed polite help u select menul tune great would like come back',
#  'bad experience herebeyond flavour really put beyond flavourshad go dinner next day get hospitalise food infectioni guess food serve fresh',
#  'lovely ambienceroasted chicken soup highlight dinnerbasket biryani full flavour yummlasagne greatnice go whole familyappetisers quantity less though',
#  'like food ambience problem staff responsive we’ve order one item get something else otherwise place food good',
#  'it’s bad service experience food ok take 45mins get veg pulav never see restaurant take time won’t visit',
#  'waiter good enough get item order overall bad experience wait time expect',
#  'awesome food good ambience centrally locate ample parkingcoordination serve boy  service scope improvement boys courteous though sure bar close saturday eveningoverall good experience  extremely value moneywill visit',
#  'office lunch out rating would mix food fine service bad book table day still wait 3040 min get one manager polite give rubbish reason bad service ambiance fine',
#  'really enjoy followsthe entrance music light seat arrangement decoration everything awsome food best service enhance flavour restaurant realy recommend restaurant',
#  'come first time restaurantthe entrance music light seat arrangement decoration everything awsome food best service enhance flavour restaurant',
#  'pathetic horrible experienceambience hospitality 1food 1chairs table break food cold tastelessbuffet arrangement good could bite spacious',
#  'ahmed serve u polite cooperative staffamazing food ambienceveg gilaffi kabab lasgna must tryloved overall experience',
#  'paradise biryani really good service also good staff friendly ambiance nice chicken biryani mutton biryani good thank',
#  'chiken biryani good andspcal chiken cary good testy foodandso enjoy food andnext time visit family friend',
#  'good hospitalitygood ambiance good food v good facility pack biriyani long distance good place visit mainly hyderabad biriyani',
#  'good food tasty well music food well quick responseand everything good good environment',
#  'goodtasteever paradise make magicchefs gladly prepare way u prefer nice serve everyonethis world best biryani',
#  'food quality goodbut sometakes time food arrivesbut food taste goodstaff goodperfect family lunch dinnerenjoy',
#  'tasty food good service  enjoy lot paradise quick response provider  fast deliverytasty food good place good economic people',
#  'order one chicken one mutton biryani good paradise definitly great restaurant biryani restaurant ambinence good along quick service',
#  'always best  time favorite food biryani ka baap  every time visit feel something special almost visit 20 time  simply best',
#  'good taste love visit  family friends hopefully enjoy taste biryani make happen every time',
#  'usual food always good  world famous biryanii love eat paradise biryani ever amservice n ambiance also good',
#  'order tandoori chicken starter thats tasty light butter naan mutton masala main course order chicken biryani egg mutton biryani tasty light mutton piecs cook perfection',
#  'fri approach service especially shri krishan excellent service render dish tasty like visit recommend friend',
#  'order drumstick chicken biryanijust awesome taste good service5 ratinggood response service boys good servinggood seating',
#  'food hospitality staff amazing service fast ambience place really good really recommened everyone try kadai chicken',
#  'service good food also good ambiance good chicken biriyani egg biriyani really good nice service good food overall good',
#  'order chicken biryani egg biriyani food awesome nice place great ambitious definitely come next time service good',
#  'friendly nice service chicken biryani deliciouscurry bowl design nice nice temp nice cool nice tooth pic nice spot selfie nice restaurant setting',
#  'nice humble staff tasty biryani many people tell try another place paradise truly paradise biryani lover',
#  'nice restaurant friendly courteous staff variety option choose curry raita really good good option veggie also try',
#  'order nut overload ice creamfantastic taste',
#  'delivery time 5 star delivery person',
#  'cream stone best hangout place come latenight drive  issue place become bit crowded order take bit extra time come',
#  'creamstone say goodnicecream weakness branch become super busy see many zomato guy line order',
#  'well love love love icecream say favourite three precise death chocolate chocolate overdose karamel sutra diet get diet fruit concept icecream mad icecreams one place gawk food forget click picture',
#  'crowd delivery executive time dont find place sit mostly itd well provide way preferable online order physical visit',
#  'cream stone always best even cake require complete still show cake online deliveryit change customer dont face trouble',
#  'whenever crave ice cream cream stone solution coffee lover first thing tried coffee craze taste really good every bite could feel crunch nut next thing tried chocolate overdose serious overdose chocolate delectable scoop icecream chocolate brownie icecreams extremely rich intense overall regret order continue try new flavour',
#  'could finish ice cream goodnever like place specially sitafal taste bad crowdy place taste good',
#  'goo blend ice cream good flavour well many variety fruit chocolate flavor try ice cram big waffle hard',
#  'poor service order ice cream take 1 hour reach meby time reach like ice cream like milk shake completely melt didnt add solid ice inside package pathetic online delivery service creamstone gachibowli branch never expect big fan creamstoneit disappoint badly poor service',
#  'cream stone always best place find variety icecream  many occasion think visit place late night taste good price moderate variety item good would definatly recommend visit',
#  'order nutella brownie get brownie vanilla ice cream shame write name ice cream correct take money correct fail make ice cream correct expect cream stone customer fool dont insult assume less intelligent',
#  'love treat cream stone every perfect treat ive try almost flavor love every single one favorite would willy wonka love chocolate im fond waffle though ice cream die 😋 definitely visit cream stone',
#  'good timing',
#  'heard lot ice cream parlour friend hyderabad chennai didnt miss visit place hyderabad order one ferrero rocher like heaven 🤩the place small indoor seat think  management increase indoor seat arrangement due large crowdif u r icecreamlover  place perfect bliss',
#  'perfect dessert must surprise gift partner 😍 try chocolate dose enjoy pure bliss chocolate mouth 😋 reduce sugar content bit 🤔',
#  'ever busy place reek laughter  sugar air cream stone brand ever know  set apart gachibowli others courteous staff  ambient seat area go place isb iiit  hcu student',
#  'totally recommended crazy ice snowpplambience 25taste 55pocket friendly 35this place dine crowdthere flavour every one',
#  'good',
#  'excellent service',
#  'super delevery',
#  'delivery behaviour good',
#  'order several time cream stoneone fine place ice cream quality taste ice cream top notch fall love ice cream',
#  'please look image get order order zomato confusion eat gulp however give 2  browny',
#  'ggod',
#  'didnt pack ice cream nicely ie didnt keep dry ice get melted spread pckage bit disappointed taste good',
#  'ice cream melt reached didnt see dry ice piece either service bad',
#  'ice cream good  totally get melt delivery boy take lot time reach mention deliver soon picked order take nearly 45 minute come',
#  '1half ice cream spill inside package only2i order caremel sutrabut get brownie ice cream3and cream liquid state like milkshakei expect cream stone alli pic',
#  ...]

# %%
def lstm_model(input_shape):

  X_indices = Input(input_shape)

  embeddings = embedding_layer(X_indices)

  X = LSTM(128, return_sequences=True)(embeddings)

  X = Dropout(0.6)(X)

  X = LSTM(128, return_sequences=True)(X)

  X = Dropout(0.6)(X)

  X = LSTM(128)(X)

  X = Dense(1, activation='sigmoid')(X)

  model = Model(inputs=X_indices, outputs=X)

  return model

# %%
def conv1d_model(input_shape):

  X_indices = Input(input_shape)

  embeddings = embedding_layer(X_indices)

  X = Conv1D(512,3,activation='relu')(embeddings)
  
  X = MaxPooling1D(3)(X)

  X = Conv1D(256,3,activation='relu')(X)
  
  X = MaxPooling1D(3)(X)

  X = Conv1D(256,3,activation='relu')(X)
  X = Dropout(0.8)(X)
  X = MaxPooling1D(3)(X)

  X = GlobalMaxPooling1D()(X)

  X = Dense(256, activation='relu')(X)
  X = Dense(1, activation='sigmoid')(X)

  model = Model(inputs=X_indices, outputs=X)

  return model

# %%
callbacks = [EarlyStopping(monitor='val_accuracy', min_delta=1e-4, patience=5)]

# %% [markdown]
# ## Word Embeddings

# %% [markdown]
# ### Bag of Words

# %%
vectorizer = CountVectorizer(max_features=10000)
x_train_bow = vectorizer.fit_transform(x_train)
x_test_bow = vectorizer.transform(x_test)

# %%
x_train_bow
# Out:
# <7963x10000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 174996 stored elements in Compressed Sparse Row format>

# %%
clf_bow = RandomForestClassifier()
clf_bow.fit(x_train_bow, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_bow = clf_bow.predict(x_test_bow)
accuracy_bow = accuracy_score(y_test, y_pred_bow)
print("Accuracy using Bag of Words:", accuracy_bow)
# Out:
# Accuracy using Bag of Words: 0.8598694123556002

# %% [markdown]
# ### Tf-idf vectorizer

# %%
vectorizer_tfidf = TfidfVectorizer(max_features=10000, lowercase=True)
x_train_tfidf = vectorizer_tfidf.fit_transform(x_train)
x_test_tfidf = vectorizer_tfidf.transform(x_test)

# %%
clf_tfidf = RandomForestClassifier()
clf_tfidf.fit(x_train_tfidf, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_tfidf = clf_tfidf.predict(x_test_tfidf)
accuracy_tfidf = accuracy_score(y_test, y_pred_tfidf)
print("Accuracy using TF IDF:", accuracy_tfidf)
# Out:
# Accuracy using TF IDF: 0.8455734406438632

# %% [markdown]
# ### GloVe

# %%
tokenizer = Tokenizer(num_words=10000, oov_token="<oov>")
tokenizer.fit_on_texts(x_train)
words_to_index = tokenizer.word_index

# %%
len(words_to_index)
# Out:
# 21183

# %%
with open('glove.6B.50d.txt', 'r', encoding='UTF-8') as f:
    words = set()
    word_to_vec_map = {}
    for line in f:
      w_line = line.split()
      curr_word = w_line[0]
      word_to_vec_map[curr_word] = np.array(w_line[1:], dtype=np.float64)

# %%
maxLen = 200

vocab_len = len(words_to_index)
embed_vector_len = word_to_vec_map['the'].shape[0]

emb_matrix = np.zeros((vocab_len, embed_vector_len))

for word, index in words_to_index.items():
  embedding_vector = word_to_vec_map.get(word)
  if embedding_vector is not None:
    emb_matrix[index, :] = embedding_vector

# %%
x_train_glove = tokenizer.texts_to_sequences(x_train)
x_test_glove = tokenizer.texts_to_sequences(x_test)

x_test_glove = pad_sequences(x_test_glove, maxlen=maxLen, padding='post')
x_train_glove = pad_sequences(x_train_glove, maxlen=maxLen, padding='post')

# %%
len(emb_matrix)
# Out:
# 21183

# %%
embedding_layer = Embedding(input_dim=vocab_len, output_dim=embed_vector_len, input_length=maxLen, weights = [emb_matrix], trainable=False)

# %%
model = lstm_model((maxLen,))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200)]             0
#
#  embedding (Embedding)       (None, 200, 50)           1059150
#
#  lstm (LSTM)                 (None, 200, 128)          91648
#
#  dropout (Dropout)           (None, 200, 128)          0
#
#  lstm_1 (LSTM)               (None, 200, 128)          131584
#
#  dropout_1 (Dropout)         (None, 200, 128)          0
#
#  lstm_2 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 1,414,095
# Trainable params: 354,945
# Non-trainable params: 1,059,150
# _________________________________________________________________

# %%
model_1d = conv1d_model((maxLen,))
model_1d.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200)]             0
#
#  embedding (Embedding)       (None, 200, 50)           1059150
#
#  conv1d (Conv1D)             (None, 198, 512)          77312
#
#  max_pooling1d (MaxPooling1D  (None, 66, 512)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 64, 256)           393472
#
#  max_pooling1d_1 (MaxPooling  (None, 21, 256)          0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 19, 256)           196864
#
#  dropout_2 (Dropout)         (None, 19, 256)           0
#
#  max_pooling1d_2 (MaxPooling  (None, 6, 256)           0
#  1D)
#
#  global_max_pooling1d (Globa  (None, 256)              0
#  lMaxPooling1D)
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 1,792,847
# Trainable params: 733,697
# Non-trainable params: 1,059,150
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(x_train_glove, y_train, epochs=15, validation_data = (x_test_glove, y_test), callbacks=callbacks)
# Out:
# Epoch 1/15
# 249/249 [==============================] - 12s 37ms/step - loss: 0.6609 - accuracy: 0.6302 - val_loss: 0.6581 - val_accuracy: 0.6434
# Epoch 2/15
# 249/249 [==============================] - 20s 81ms/step - loss: 0.6592 - accuracy: 0.6320 - val_loss: 0.6540 - val_accuracy: 0.6434
# Epoch 3/15
# 249/249 [==============================] - 12s 49ms/step - loss: 0.6587 - accuracy: 0.6320 - val_loss: 0.6578 - val_accuracy: 0.6434
# Epoch 4/15
# 249/249 [==============================] - 9s 36ms/step - loss: 0.6588 - accuracy: 0.6320 - val_loss: 0.6535 - val_accuracy: 0.6434
# Epoch 5/15
# 249/249 [==============================] - 8s 34ms/step - loss: 0.6585 - accuracy: 0.6320 - val_loss: 0.6551 - val_accuracy: 0.6434
# Epoch 6/15
# 249/249 [==============================] - 8s 33ms/step - loss: 0.6591 - accuracy: 0.6320 - val_loss: 0.6520 - val_accuracy: 0.6434
# Epoch 7/15
# 249/249 [==============================] - 8s 32ms/step - loss: 0.6582 - accuracy: 0.6320 - val_loss: 0.6530 - val_accuracy: 0.6434
# Epoch 8/15
# 249/249 [==============================] - 12s 49ms/step - loss: 0.6575 - accuracy: 0.6320 - val_loss: 0.6568 - val_accuracy: 0.6434
# Epoch 9/15
# 249/249 [==============================] - 12s 48ms/step - loss: 0.6579 - accuracy: 0.6322 - val_loss: 0.6536 - val_accuracy: 0.6429
# Epoch 10/15
# 249/249 [==============================] - 9s 34ms/step - loss: 0.6573 - accuracy: 0.6323 - val_loss: 0.6525 - val_accuracy: 0.6444
# Epoch 11/15
# 249/249 [==============================] - 9s 35ms/step - loss: 0.6605 - accuracy: 0.6325 - val_loss: 0.6788 - val_accuracy: 0.6434
# Epoch 12/15
# 249/249 [==============================] - 9s 35ms/step - loss: 0.6670 - accuracy: 0.6239 - val_loss: 0.6532 - val_accuracy: 0.6434
# Epoch 13/15
# 249/249 [==============================] - 9s 35ms/step - loss: 0.6600 - accuracy: 0.6320 - val_loss: 0.6514 - val_accuracy: 0.6434
# Epoch 14/15
# 249/249 [==============================] - 9s 34ms/step - loss: 0.6589 - accuracy: 0.6320 - val_loss: 0.6513 - val_accuracy: 0.6434
# Epoch 15/15
# 249/249 [==============================] - 9s 35ms/step - loss: 0.6586 - accuracy: 0.6320 - val_loss: 0.6556 - val_accuracy: 0.6434

# %%
model_1d.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_1d.fit(x_train_glove, y_train, epochs=15, validation_data = (x_test_glove, y_test), callbacks=callbacks)
# Out:
# Epoch 1/15
# 249/249 [==============================] - 3s 6ms/step - loss: 0.5684 - accuracy: 0.7177 - val_loss: 0.4968 - val_accuracy: 0.8089
# Epoch 2/15
# 249/249 [==============================] - 1s 5ms/step - loss: 0.4015 - accuracy: 0.8258 - val_loss: 0.4080 - val_accuracy: 0.8275
# Epoch 3/15
# 249/249 [==============================] - 1s 5ms/step - loss: 0.3309 - accuracy: 0.8624 - val_loss: 0.4184 - val_accuracy: 0.8330
# Epoch 4/15
# 249/249 [==============================] - 1s 5ms/step - loss: 0.2909 - accuracy: 0.8827 - val_loss: 0.4270 - val_accuracy: 0.8023
# Epoch 5/15
# 249/249 [==============================] - 1s 5ms/step - loss: 0.2366 - accuracy: 0.9049 - val_loss: 0.3967 - val_accuracy: 0.8300
# Epoch 6/15
# 249/249 [==============================] - 1s 5ms/step - loss: 0.1769 - accuracy: 0.9302 - val_loss: 0.4034 - val_accuracy: 0.8315
# Epoch 7/15
# 249/249 [==============================] - 1s 5ms/step - loss: 0.1453 - accuracy: 0.9423 - val_loss: 0.4200 - val_accuracy: 0.8204
# Epoch 8/15
# 249/249 [==============================] - 1s 5ms/step - loss: 0.1304 - accuracy: 0.9484 - val_loss: 0.4500 - val_accuracy: 0.8084
# Epoch 9/15
# 249/249 [==============================] - 1s 5ms/step - loss: 0.1097 - accuracy: 0.9576 - val_loss: 0.4977 - val_accuracy: 0.8224
# Epoch 10/15
# 249/249 [==============================] - 1s 5ms/step - loss: 0.0822 - accuracy: 0.9708 - val_loss: 0.5093 - val_accuracy: 0.8255
# Epoch 11/15
# 249/249 [==============================] - 1s 5ms/step - loss: 0.0917 - accuracy: 0.9672 - val_loss: 0.5374 - val_accuracy: 0.8174
# Epoch 12/15
# 249/249 [==============================] - 1s 5ms/step - loss: 0.0718 - accuracy: 0.9743 - val_loss: 0.7871 - val_accuracy: 0.7797
# Epoch 13/15
# 249/249 [==============================] - 1s 5ms/step - loss: 0.0860 - accuracy: 0.9692 - val_loss: 0.5623 - val_accuracy: 0.8325
# Epoch 14/15
# 249/249 [==============================] - 1s 5ms/step - loss: 0.0672 - accuracy: 0.9765 - val_loss: 0.5517 - val_accuracy: 0.8219
# Epoch 15/15
# 249/249 [==============================] - 1s 5ms/step - loss: 0.0548 - accuracy: 0.9809 - val_loss: 0.6303 - val_accuracy: 0.8255

# %%
model_1d.save_weights('glove_weights_con1vd.hdf5')
model.save_weights('glove_weights_lstm.hdf5')

# %%
x_train, x_test, y_train, y_test = train_test_split(pd.DataFrame(data['tokens']), pd.DataFrame(data['Sentiment']), test_size=0.2, random_state=42)

# %%
class W2vVectorizer(object):
    """Class to generate mean word embeddings from word vectors. This class is
    quoted from Flatiron School Curriculum Learn.co Mod 4 appendix"""
    def __init__(self, w2v):
        # Takes in a dictionary of words and vectors as input
        self.w2v = w2v
        if len(w2v) == 0:
            self.dimensions = 0
        else:
            self.dimensions = len(w2v[next(iter(word_to_vec_map))])
    
    # Note: Even though it doesn't do anything, 
    # it's required that this object implement a fit method or else
    # it can't be used in a scikit-learn pipeline  
    def fit(self, X, y):
        return self
            
    def transform(self, X):
        # X should be a series of lists of tokens
        return np.array([
            np.mean([self.w2v[w] for w in words if w in self.w2v]
                   or [np.zeros(self.dimensions)], axis=0) for words in X])

# %%
x_train
# Out:
# 715     tried 5 high rating shawarma place hyderabad b...
# 809     good taste food nice ambiencestaff really frie...
# 3205    look north indian food must say liked alot amb...
# 7532    order special chicken biryani awsomeand good c...
# 6435                                        fast delivery
#                               ...
# 5734                                      awesome service
# 5191                            reach delivery time thanq
# 5390        superb taste little delay get product deliver
# 860     amaze ipl offer600 4 pint  french friesnice am...
# 7270    absolutely delighted overall experience shop e...
# Name: Clean_Review, Length: 7952, dtype: object

# %%
vectorizer = W2vVectorizer(word_to_vec_map)
x_train_glove = vectorizer.transform(x_train.tokens)

# %%
x_test_glove = vectorizer.transform(x_test.tokens)

# %%
clf_glove = RandomForestClassifier()
clf_glove.fit(x_train_glove, y_train)
# Out:
# c:\Users\Anantha\miniconda3\envs\gpukeras\lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
y_pred_glove = clf_glove.predict(x_test_glove)
accuracy_glove = accuracy_score(y_test, y_pred_glove)
print("Accuracy using Glove:", accuracy_glove)
# Out:
# Accuracy using Glove: 0.790241448692153

# %% [markdown]
# ### Word2Vec

# %%
Embedding_dimensions = 100

Word2vec_train_data = list(map(lambda x: x.split(), x_train))

# %%
Word2vec_train_data
# Out:
# [['tried',
#   '5',
#   'high',
#   'rating',
#   'shawarma',
#   'place',
#   'hyderabad',
#   'best',
#   'fill',
#   'place',
#   'simply',
#   'amaze',
#   'special',
#   'rumali',
#   'best'],
#  ['good',
#   'taste',
#   'food',
#   'nice',
#   'ambiencestaff',
#   'really',
#   'friendlysandipmusic',
#   'really',
#   'good',
#   'atmosphere',
#   'energeticits',
#   'good',
#   'place',
#   'njoy',
#   'friend',
#   'family'],
#  ['look',
#   'north',
#   'indian',
#   'food',
#   'must',
#   'say',
#   'liked',
#   'alot',
#   'ambience',
#   'good',
#   'service',
#   'good',
#   'regular',
#   'place',
#   'go',
#   'place',
#   'would',
#   'say',
#   'know',
#   'miss',
#   'place',
#   'try',
#   'schezwan',
#   'fry',
#   'rice',
#   'kadai',
#   'paneer',
#   'roti',
#   'friend',
#   'plan',
#   'try',
#   'buffet',
#   'next',
#   'time',
#   '45',
#   'side',
#   '❤😊'],
#  ['order',
#   'special',
#   'chicken',
#   'biryani',
#   'awsomeand',
#   'good',
#   'crevice',
#   'tasty',
#   'good',
#   'ambience',
#   '35',
#   'food',
#   '55',
#   'service',
#   '55',
#   'expense',
#   'good'],
#  ['fast', 'delivery'],
#  ['pathetic',
#   'restuarant',
#   'struggle',
#   'even',
#   'get',
#   'table',
#   'pay',
#   'cover',
#   'charge',
#   'struggle',
#   'mess',
#   'everything',
#   'order',
#   'chilly',
#   'paneer',
#   'get',
#   'chilly',
#   'chicken',
#   'mean',
#   'restuarant',
#   'ask',
#   'manager',
#   'atleast',
#   '3',
#   '4',
#   'time',
#   'get',
#   'every',
#   'order',
#   'take',
#   '45',
#   'minute',
#   'get',
#   'order',
#   'crowd',
#   'space',
#   'dance',
#   'people',
#   'dance',
#   'near',
#   'table',
#   'drink',
#   'spell',
#   '3',
#   '4',
#   'time',
#   'complain',
#   'nobody',
#   'even',
#   'bother',
#   'check',
#   'last',
#   'saw',
#   'bill',
#   'almost',
#   '3',
#   '4',
#   'item',
#   'include',
#   'never',
#   'order',
#   'horrible',
#   'experience',
#   'waste',
#   'money',
#   'time',
#   'energy'],
#  ['visited',
#   'place',
#   'saturday',
#   'evening',
#   'cause',
#   'ive',
#   'heard',
#   'lot',
#   'tiki',
#   'shack',
#   'ambience',
#   'pretty',
#   'decent',
#   'beautiful',
#   'roof',
#   'top',
#   'view',
#   'honestly',
#   'surprise',
#   'food',
#   'wasnt',
#   'great',
#   'infact',
#   'think',
#   'bad',
#   'enough',
#   'ive',
#   'heard',
#   'peopleordered',
#   'non',
#   'veg',
#   'nacho',
#   'hardly',
#   'find',
#   'non',
#   'veg',
#   'pizza',
#   'quite',
#   'bland',
#   'one',
#   'really',
#   'bad',
#   'pepporoni',
#   'pizza',
#   'ive',
#   'lifefood',
#   '35',
#   '3',
#   'cause',
#   'service',
#   'nice',
#   'people'],
#  ['order',
#   'paneer',
#   'tikka',
#   'garden',
#   'fresh',
#   'sandwich',
#   'oreo',
#   'shake',
#   'paneer',
#   'tikka',
#   '55garden',
#   'fresh',
#   '55oreo',
#   'shake',
#   '45',
#   'cold',
#   'staff',
#   '15',
#   'request',
#   'change',
#   'would',
#   'behave',
#   'like',
#   'kid',
#   'flexible',
#   'remove',
#   'top',
#   'would',
#   'cost',
#   'anything',
#   'deny',
#   'something',
#   'terrible',
#   'thereoverall',
#   'ambiance',
#   'good',
#   'ac',
#   'work',
#   'properly',
#   'bit',
#   'dull',
#   'therefacebookcom'],
#  ['wonderful',
#   'food',
#   'ambiance',
#   'best',
#   'place',
#   'family',
#   'food',
#   'exotic',
#   'staff',
#   'courteous',
#   'value',
#   'money',
#   'family',
#   'good',
#   'time'],
#  ['go',
#   'cafe',
#   'discussion',
#   'meeting',
#   'place',
#   '10',
#   'time',
#   'never',
#   'get',
#   'disappointedthe',
#   'ambience',
#   'stand',
#   'nearby',
#   'place',
#   'whole',
#   'garage',
#   'theme',
#   'look',
#   'closely',
#   'table',
#   'first',
#   'floor',
#   'actually',
#   'make',
#   'car',
#   'truck',
#   'part',
#   'well',
#   'much',
#   'innovation',
#   'think',
#   'mind',
#   'blow',
#   'wall',
#   'next',
#   'stair',
#   'full',
#   'picture',
#   'photogenic',
#   'cherry',
#   'top',
#   'song',
#   'selectionall',
#   'coffee',
#   'taste',
#   'great',
#   'especially',
#   'fact',
#   'get',
#   'even',
#   'midnight',
#   'although',
#   'personal',
#   'favourite',
#   'flat',
#   'white',
#   'cappuccino',
#   'quite',
#   'bite',
#   'available',
#   'paneer',
#   'kulcha',
#   'recommend',
#   'well',
#   'dont',
#   'forget',
#   'take',
#   'good',
#   'camera',
#   'along',
#   'go'],
#  ['go',
#   'lunch',
#   'food',
#   'quality',
#   'good',
#   'feel',
#   'variety',
#   'could',
#   'improve',
#   'overall',
#   'nice',
#   'place',
#   'good',
#   'food',
#   'great'],
#  ['test', 'good', 'food', 'hot'],
#  ['ambience',
#   '55food',
#   '45food',
#   'awesome',
#   'best',
#   'part',
#   'ask',
#   'curry',
#   'outside',
#   'menu',
#   'well',
#   'serve',
#   'thatservice',
#   '55it',
#   'wonderful',
#   'love',
#   'politeness',
#   'staffvalue',
#   'money',
#   '55with',
#   'taste',
#   'ambience',
#   'service',
#   'totally',
#   'worth',
#   'eatingonly',
#   'thing',
#   'would',
#   'complain',
#   'staff',
#   'need',
#   'clarity',
#   'zomato',
#   'gold',
#   'give',
#   'wrong',
#   'bill',
#   'take',
#   'sometime',
#   'make',
#   'understand',
#   'way',
#   'deduction',
#   'comply',
#   'tc',
#   'give',
#   'zomato',
#   'hope',
#   'take',
#   'care',
#   'customer',
#   'face',
#   'inconvenience'],
#  ['ok'],
#  ['great',
#   'staff',
#   'niranjan',
#   'great',
#   'help',
#   'great',
#   'job',
#   'thumbs',
#   'starter',
#   'great',
#   'choice',
#   'dessert',
#   '👍😊'],
#  ['first',
#   'visit',
#   'ambience',
#   'nice',
#   'felt',
#   'food',
#   'okaybasa',
#   'fish',
#   'tikka',
#   'wasnt',
#   'soft',
#   'melt',
#   'mouth',
#   'normally',
#   'good',
#   'tikkas',
#   'would',
#   'rate',
#   '35marsala',
#   'special',
#   'chicken',
#   'curry',
#   'nothing',
#   'special',
#   'preparation',
#   'except',
#   'serve',
#   'omlet',
#   '35'],
#  ['good',
#   'rooftop',
#   'location',
#   'however',
#   'ambience',
#   'set',
#   'properly',
#   'average',
#   'service',
#   'uninterested',
#   'service',
#   'manager',
#   'disappoint',
#   'go',
#   'time',
#   'limited',
#   'product',
#   'availability',
#   'mostly',
#   'dont',
#   'get',
#   'product',
#   'want',
#   'order',
#   'give',
#   'limited',
#   'choice'],
#  ['new',
#   'job',
#   'party',
#   'lot',
#   'fun',
#   'food',
#   'absolutely',
#   'stupendous',
#   'staff',
#   'welcome',
#   'kudos',
#   'table',
#   'coordinator',
#   'mr',
#   'shekhar',
#   'take',
#   'care',
#   'every',
#   'request',
#   'keep',
#   'good',
#   'work'],
#  ['good', 'service'],
#  ['situated',
#   'heart',
#   'town',
#   'far',
#   'best',
#   'place',
#   'lay',
#   'hand',
#   'arabian',
#   'yemeni',
#   'dish',
#   'city',
#   'nawabs',
#   'stiff',
#   'competition',
#   'dozen',
#   'restaurant',
#   'area',
#   'price',
#   'average',
#   'quality',
#   'exceptional',
#   'ambience',
#   'place',
#   'exceptional',
#   'adequate',
#   'light',
#   'extremely',
#   'soothe',
#   'eye',
#   'food',
#   'apart',
#   'whole',
#   'setup',
#   'restaurant',
#   'create',
#   'unique',
#   'aura',
#   'food',
#   'loversnote',
#   'plz',
#   'try',
#   'bbq',
#   'chicken',
#   'mandi',
#   'juicy',
#   'chicken',
#   'mandi',
#   'best',
#   'item',
#   'whole',
#   'menuin',
#   'frame',
#   'bbq',
#   'chicken',
#   'mandi',
#   'chicken',
#   'juicy',
#   'mandi'],
#  ['place',
#   'nice',
#   'formal',
#   'dinner',
#   'family',
#   'dinner',
#   'comfortable',
#   'place',
#   'service',
#   'quickbarbeque',
#   'starter',
#   'good',
#   'food',
#   'average'],
#  ['late', 'delivery', 'cold', 'food'],
#  ['lunch',
#   'buffet',
#   'today',
#   'disappoint',
#   'choice',
#   'food',
#   'cant',
#   'order',
#   'mean',
#   'mention',
#   'food',
#   'menu',
#   'le',
#   'food',
#   'option',
#   'compare',
#   'others',
#   'brand',
#   'levelbut',
#   'ambiance',
#   'good',
#   'pleasant',
#   'peacefulservice',
#   'also',
#   'good',
#   'polite'],
#  ['order',
#   'dal',
#   'makkhani',
#   'rice',
#   'multiple',
#   'time',
#   'panner',
#   'paratha',
#   'good',
#   'quantity',
#   'le',
#   'one',
#   'person',
#   'even',
#   'large',
#   'size',
#   'serve',
#   'small',
#   'medium',
#   'sizepackaging',
#   'nice',
#   'although',
#   'separate',
#   'food',
#   'cant',
#   'store',
#   'suppose',
#   'eaten',
#   'order',
#   'dal',
#   'rice',
#   'pack',
#   'together',
#   'food',
#   'seem',
#   'hygienic',
#   'need',
#   'work',
#   'quantity',
#   'different',
#   'size',
#   'meal',
#   'enough'],
#  ['excellent',
#   'service',
#   'nandan',
#   'rahmat',
#   'ripan',
#   'feel',
#   'happy',
#   'management',
#   'food',
#   'awesome',
#   'expect',
#   'come',
#   'soon',
#   'abs',
#   'service',
#   'boy',
#   'fantastic'],
#  ['taste',
#   'good',
#   'also',
#   'freshly',
#   'prepared',
#   'seem',
#   'food',
#   'cook',
#   'afternoon',
#   'deliver',
#   'evening',
#   'dinner',
#   'also',
#   'spicy'],
#  ['worst',
#   'customer',
#   'service',
#   'ever',
#   'hope',
#   'place',
#   'close',
#   'good',
#   'destroy',
#   'good',
#   'day',
#   'think',
#   'visit',
#   'hope',
#   'review',
#   'save',
#   'someone'],
#  ['nice',
#   'food',
#   'awesome',
#   'service',
#   'govind',
#   'recommend',
#   'best',
#   'time',
#   'dinning😍',
#   'dessert',
#   'ware',
#   'good',
#   'gulagamun',
#   'withvennla',
#   'iceberg',
#   'also',
#   'biriyani',
#   'good',
#   'nice',
#   'place',
#   'every',
#   'thing',
#   'need',
#   'last',
#   'least',
#   'place',
#   'supper',
#   'food'],
#  ['time',
#   'favorite',
#   'sweet',
#   'lover',
#   'ferrero',
#   'rocher',
#   'pastry',
#   'must',
#   'try',
#   'also',
#   'nutella',
#   'cupcake',
#   'die',
#   'perfect',
#   'blend',
#   'chocolate',
#   'sugar',
#   'also',
#   'try',
#   'oreo',
#   'pastry'],
#  ['another',
#   'place',
#   'fo',
#   'delicious',
#   'hyderabadi',
#   'rum',
#   'biryani',
#   'irani',
#   'chaithere',
#   'numerous',
#   'place',
#   'across',
#   'city',
#   'dum',
#   'biryani',
#   'one',
#   'thr',
#   'best',
#   'although',
#   'spice',
#   'use',
#   'cook',
#   'process',
#   'every',
#   'biryani',
#   'different',
#   'flavourthis',
#   'pocket',
#   'friendly',
#   'place',
#   'available',
#   'late',
#   'nightboth',
#   'chicken',
#   'mutton',
#   'biryani',
#   'good',
#   'also',
#   'serve',
#   'fish',
#   'biryani',
#   'also',
#   'must',
#   'try',
#   'dish',
#   'kebab',
#   'also',
#   'good',
#   'herecoming',
#   'ambience',
#   'huge',
#   'place',
#   'chai',
#   'cafe',
#   'kind',
#   'ambiance',
#   'also',
#   'ac',
#   'hall',
#   'family',
#   'sectionservice',
#   'terrible',
#   'thing',
#   'even',
#   'peek',
#   'lunch',
#   'time',
#   'say',
#   'biryani',
#   'fresh',
#   'hundi',
#   'await',
#   'terriblei',
#   'mostly',
#   'take',
#   'away',
#   'good',
#   'optiontaste',
#   '4ambience',
#   '3service',
#   '3'],
#  ['become',
#   'favourite',
#   'place',
#   'parathas',
#   'serve',
#   'excellent',
#   'quality',
#   'ample',
#   'quantity',
#   'food',
#   'fully',
#   'paisa',
#   'wasool',
#   'placei',
#   'order',
#   'paneer',
#   'aloo',
#   'paratha',
#   'think',
#   'small',
#   'paratha',
#   'deliver',
#   'pleasant',
#   'surprise',
#   'two',
#   'monster',
#   'size',
#   'parathas',
#   'flavour',
#   'deliver',
#   'pack',
#   'perfect',
#   'reach',
#   'home',
#   'hot',
#   'fresh',
#   'type',
#   'parathas',
#   'really',
#   'crumptious',
#   'even',
#   'green',
#   'chutney',
#   'serve',
#   'awesome',
#   'complain',
#   'less',
#   'stuffing',
#   'inside',
#   'paratha',
#   'definitely',
#   'try',
#   'sure',
#   'disappointed',
#   'undoubtedly',
#   'full',
#   'mark',
#   'foodfollow',
#   'instagram',
#   'veganyums',
#   'food',
#   'fun'],
#  ['food',
#   'ok',
#   'service',
#   'worst',
#   'ever',
#   '34hrs',
#   'free',
#   'time',
#   'spend',
#   'come',
#   'service',
#   'slow',
#   'sloth',
#   'ordered',
#   'starter',
#   'get',
#   '30min',
#   'get',
#   'lunch',
#   'hour',
#   'guess',
#   'forget',
#   'order',
#   'give',
#   'remind',
#   'atleast',
#   'twice',
#   'thrice',
#   'get'],
#  ['food', 'salty', 'tweet', 'bad', 'food'],
#  ['love',
#   'dessert',
#   'try',
#   'almost',
#   'variety',
#   'blueberry',
#   'cheesecake',
#   'time',
#   'fav',
#   'though',
#   'also',
#   'love',
#   'sandwich',
#   'red',
#   'velvet',
#   'cupcake',
#   'osmania',
#   'biscuit',
#   'must',
#   'buy',
#   'thing',
#   'leave',
#   'hyderabad'],
#  ['right', 'time', 'time'],
#  ['review',
#   'long',
#   'overdue',
#   'visited',
#   'place',
#   'birthday',
#   'gawd',
#   'wasn’t',
#   'disappoint',
#   'place',
#   'really',
#   'sophisticated',
#   'minimal',
#   'design',
#   'isn’t',
#   'catchy',
#   'kinda',
#   'look',
#   'like',
#   'elite',
#   'ball',
#   'room',
#   'din',
#   'roomthe',
#   'service',
#   'amaze',
#   'every',
#   'staff',
#   'member',
#   'approach',
#   'table',
#   'know',
#   'menu',
#   'warmth',
#   'give',
#   'place',
#   'extra',
#   'pointsnow',
#   'come',
#   'main',
#   'aspect',
#   'restaurant',
#   'food',
#   'food',
#   'authentic',
#   'get',
#   'go',
#   'every',
#   'cuisine',
#   'restaurant',
#   'offer',
#   'mediterranean',
#   'italian',
#   'matter',
#   'fact',
#   'even',
#   'indiannow',
#   'don’t',
#   'want',
#   'go',
#   'detail',
#   'order',
#   'describe',
#   'i’ll',
#   'attach',
#   'image',
#   'review',
#   'i’ll',
#   'let',
#   'image',
#   'talk',
#   'albeit',
#   'i’d',
#   'like',
#   'describe',
#   'dish',
#   'dish',
#   'deserve',
#   'credit',
#   'begin',
#   'i’d',
#   'like',
#   'talk',
#   'pizza',
#   'one',
#   'fine',
#   'pizza',
#   'i’ve',
#   'ever',
#   'hyderabad',
#   'drizzle',
#   'tad',
#   'bit',
#   'olive',
#   'oil',
#   'perfectly',
#   'seasonedmoving',
#   'forward',
#   'i’d',
#   'like',
#   'talk',
#   'mutabak',
#   'chef',
#   'take',
#   'pedantic',
#   'effort',
#   'make',
#   'dish',
#   'authentic',
#   'could',
#   'get',
#   'i’d',
#   'give',
#   'brownie',
#   'point',
#   'painstaking',
#   'ability',
#   'make',
#   'dish',
#   'omelet',
#   'perfectly',
#   'cook',
#   'crisp',
#   'like',
#   'replica',
#   'mutabak',
#   'available',
#   'call',
#   'mediterranean',
#   'restaurant',
#   'carbonara',
#   'perfectly',
#   'cook',
#   'italian',
#   'way',
#   'black',
#   'pepper',
#   'stick',
#   'piece',
#   'pasta',
#   'show',
#   'well',
#   'verse',
#   'chef',
#   'recipeto',
#   'summarize',
#   'i’d',
#   'say',
#   'yes',
#   'place',
#   'must',
#   'visit',
#   'i’d',
#   'definitely',
#   'recommend',
#   'formal',
#   'casual',
#   'occasion',
#   'birthday',
#   'cooperate',
#   'dinner',
#   'place',
#   'place'],
#  ['visited',
#   'afternoon',
#   'pleasant',
#   'ambience',
#   'temple',
#   'like',
#   'feel',
#   'bell',
#   'door',
#   'idol',
#   'entrance',
#   'order',
#   'north',
#   'indian',
#   'thali',
#   'taste',
#   'okay',
#   'extraordinary',
#   'thali',
#   'though',
#   'served',
#   'butter',
#   'rotis',
#   'jeera',
#   'rice',
#   'white',
#   'rice5',
#   'curry',
#   'dal',
#   'payasam',
#   'kheer',
#   'kheer',
#   'highlight',
#   'want',
#   'call',
#   'outambience',
#   '35food',
#   '35service',
#   '45'],
#  ['go',
#   'lunch',
#   'place',
#   'friday',
#   'full',
#   'crowd',
#   'wait',
#   'almost',
#   '1hr',
#   'want',
#   'go',
#   'place',
#   'first',
#   'reserve',
#   'tablecoming',
#   'taste',
#   'awesome',
#   'raju',
#   'gari',
#   'kodi',
#   'palav',
#   'ulavacharu',
#   'biryani',
#   'chicken',
#   'vepudu',
#   'really',
#   'good',
#   'serving',
#   'also',
#   'fast'],
#  ['service',
#   'really',
#   'exceptional',
#   'cheer',
#   'manav',
#   'serve',
#   'u',
#   'really',
#   'well',
#   'food',
#   'nice',
#   'love',
#   'ambience',
#   'nice',
#   'music',
#   'playing',
#   'background'],
#  ['review',
#   'delivery',
#   'order',
#   'half',
#   'kg',
#   'butterscotch',
#   'cake',
#   'really',
#   'really',
#   'great',
#   'taste',
#   'texture',
#   'cake',
#   'perfect',
#   'amount',
#   'butterscotch',
#   'make',
#   'specialedited',
#   'review',
#   'finally',
#   'go',
#   'outlet',
#   'soon',
#   'enter',
#   'food',
#   'fragrance',
#   'get',
#   'u',
#   'order',
#   'snavks',
#   'good'],
#  ['short',
#   'review',
#   'decent',
#   'bread',
#   'starter',
#   'bad',
#   'shaam',
#   'savera',
#   'little',
#   'screw',
#   'daal',
#   'makhni',
#   'oneoff',
#   'casebetter',
#   'ambience',
#   'night',
#   'importantly',
#   'good',
#   'quantityi',
#   'want',
#   'give',
#   '25',
#   'thats',
#   'option',
#   '🙈extensiveambience',
#   'well',
#   'night',
#   'friend',
#   'day',
#   'didnt',
#   'like',
#   'much',
#   'prefer',
#   'ambience',
#   'go',
#   'nightfood',
#   'order',
#   'hara',
#   'bhara',
#   'kebab',
#   'shaam',
#   'savera',
#   'daal',
#   'makhni',
#   'rotis',
#   'raita',
#   'yes',
#   'im',
#   'vegetarian',
#   '🙈the',
#   'good',
#   'part',
#   'quantity',
#   '😍i',
#   'excite',
#   'see',
#   'shaam',
#   'savera',
#   'menu',
#   'take',
#   'want',
#   'order',
#   'close',
#   'mess',
#   'real',
#   'bad',
#   'especially',
#   'colorsthe',
#   'daal',
#   'makhni',
#   'big',
#   'chunk',
#   'garlic',
#   'clove',
#   'spoil',
#   'wasnt',
#   'creamy',
#   'bread',
#   'raita',
#   'decentthe',
#   'hara',
#   'bhara',
#   'kebab',
#   'decent',
#   'soft',
#   'extra',
#   'outer',
#   'coat',
#   'peanut',
#   'youre',
#   'peanut',
#   'fan',
#   'kebabs',
#   'ask',
#   'skip',
#   'step',
#   '🙈conclusion',
#   'look',
#   'like',
#   'make',
#   'food',
#   'hurrywould',
#   'like',
#   'give',
#   'place',
#   'another',
#   'try',
#   'hop',
#   'mine',
#   'one',
#   'odd',
#   'case',
#   'thing',
#   'change',
#   'youll',
#   'know'],
#  ['nice'],
#  ['tasty'],
#  ['low', 'quality'],
#  ['delivery', 'taste', 'wasnt', 'good'],
#  ['excellent',
#   'food',
#   'good',
#   'service',
#   'good',
#   'value',
#   'money',
#   'nice',
#   'ambience',
#   'wish',
#   'everybody',
#   'try',
#   'restaurant',
#   'u',
#   'satisfy',
#   'thank',
#   'md',
#   'alam'],
#  ['locate',
#   'top',
#   'floor',
#   'sln',
#   'terminus',
#   'one',
#   'food',
#   'court',
#   'corner',
#   'norfest',
#   'dhaba',
#   'well',
#   'arrange',
#   'menu',
#   'delivery',
#   'table',
#   'unlike',
#   'stall',
#   'ambience',
#   'good',
#   'go',
#   'weekday',
#   'less',
#   'crowded',
#   'order',
#   'special',
#   'veg',
#   'dum',
#   'pulao',
#   'rice',
#   'well',
#   'cook',
#   'didnt',
#   'find',
#   'lot',
#   'veggie',
#   'though',
#   'masala',
#   'level',
#   'good',
#   'add',
#   'spicyness',
#   'give',
#   'try',
#   '180',
#   'buck'],
#  ['visited',
#   'office',
#   'friend',
#   'first',
#   'thing',
#   'first',
#   'staff',
#   'polite',
#   'prompt',
#   'keep',
#   'ask',
#   'bring',
#   'u',
#   'next',
#   'keep',
#   'try',
#   'feed',
#   'u',
#   '😄',
#   'even',
#   'ask',
#   'change',
#   'barbecue',
#   'seem',
#   'one',
#   'hot',
#   'enough',
#   'server',
#   'try',
#   'explain',
#   'much',
#   'heat',
#   'good',
#   'might',
#   'spoilovercook',
#   'food',
#   'insist',
#   'politely',
#   'change',
#   'barbecuecoming',
#   'foodvegetarian',
#   'variety',
#   'dish',
#   'paneer',
#   'mushroom',
#   'crispy',
#   'corn',
#   'potato',
#   'etc',
#   'starter',
#   'yes',
#   'place',
#   'good',
#   'enough',
#   'vegetarian',
#   'toonon',
#   'vegetarian',
#   'starter',
#   'basic',
#   'chicken',
#   'tandoorileg',
#   'fish',
#   'prawn',
#   'mutton',
#   'seek',
#   'kabab',
#   'must',
#   'try',
#   'etcthe',
#   'main',
#   'course',
#   'like',
#   'buffet',
#   'place',
#   'interest',
#   'noodle',
#   'one',
#   'personal',
#   'favourite',
#   'little',
#   'disappointingthe',
#   'sweet',
#   'section',
#   'would',
#   'make',
#   'anyone',
#   'happy',
#   'thing',
#   'notice',
#   'even',
#   'though',
#   'stay',
#   'till',
#   'outlet',
#   'almost',
#   'go',
#   'close',
#   'sweet',
#   'cornor',
#   'refill',
#   'timeagain',
#   'kudos',
#   'server',
#   'make',
#   'happy',
#   'experience'],
#  ['wow',
#   'zega',
#   'people',
#   'best',
#   'city',
#   'rock',
#   'ice',
#   'innovation',
#   'cocktails',
#   'attract',
#   'time',
#   'thank',
#   'much',
#   'give',
#   'surprise',
#   'time'],
#  ['visited',
#   'place',
#   'weeknight',
#   'less',
#   'crowd',
#   'veg',
#   'food',
#   'okay',
#   'nonveg',
#   'side',
#   'try',
#   'buffet',
#   'serve',
#   'soup',
#   '2',
#   'starter',
#   'salad',
#   'veg',
#   'starter',
#   'soup',
#   'starter',
#   'apolo',
#   'fish',
#   'chicken',
#   'kebab',
#   'even',
#   'close',
#   'kebab',
#   'good',
#   'curry',
#   'roti',
#   'okay',
#   'biryani',
#   'serve',
#   'tasty',
#   'overall',
#   'food',
#   'bad',
#   'reasonable',
#   'rate',
#   'place',
#   'comfortable',
#   'service',
#   'quick'],
#  ['good'],
#  ['taste', 'good'],
#  ['excellent',
#   'taste',
#   'replacement',
#   'shahghouse',
#   'shawarma',
#   'quantity',
#   'worth',
#   'delay',
#   'delivery',
#   'unique',
#   'taste',
#   'try',
#   'without',
#   'doubt',
#   'addict'],
#  ['dj',
#   'floor',
#   'best',
#   'part',
#   'skyhy',
#   '💃the',
#   'name',
#   'lounge',
#   'justify',
#   'decent',
#   'rooftopipl',
#   't20',
#   'time',
#   'best',
#   'visit',
#   'placealthough',
#   'food',
#   'drink',
#   'quality',
#   'need',
#   'improve',
#   'little',
#   'bad',
#   'experience',
#   'couple',
#   'visit'],
#  ['go',
#   'place',
#   'lot',
#   'expectationsi',
#   'travel',
#   '30',
#   'km',
#   'full',
#   'curiosity',
#   'reach',
#   'cafe',
#   'order',
#   'food',
#   'go',
#   'explore',
#   'cafe',
#   'good',
#   'bike',
#   'car',
#   'surround',
#   'theme',
#   'cafe',
#   'good',
#   'wait',
#   '30',
#   'min',
#   'bcoz',
#   'top',
#   'floor',
#   'cafe',
#   'maintenance',
#   'see',
#   'ambience',
#   'cafe',
#   'wait',
#   'go',
#   'upto',
#   'find',
#   'intresting',
#   'stuff',
#   'satisfy',
#   'btw',
#   'food',
#   'good'],
#  ['late',
#   'review',
#   'dinner',
#   'deinks',
#   'nice',
#   'small',
#   'place',
#   'good',
#   'vibe',
#   'cocktail',
#   'make',
#   'well',
#   'issue',
#   'gold',
#   'go',
#   'frio',
#   'later',
#   'dessert'],
#  ['saturday',
#   'night',
#   'band',
#   'performance',
#   'well',
#   'nice',
#   'music',
#   'performingplaying',
#   'bollywood',
#   'sufi',
#   'track',
#   'seat',
#   'outside',
#   'bandoverall',
#   'pocket',
#   'friendly',
#   'well',
#   'beer',
#   'lover'],
#  ['awesome',
#   'place',
#   'usual',
#   'hangout',
#   'like',
#   'fresh',
#   'brew',
#   'beer',
#   'great',
#   'music',
#   'lovely',
#   'ambience',
#   'best',
#   'part',
#   'really',
#   'friendly',
#   'efficient',
#   'staff',
#   'keshav',
#   'lead',
#   'pack',
#   'don’t',
#   'miss',
#   'burmese',
#   'parcel',
#   '3',
#   'cheese',
#   'mushroom',
#   'non',
#   'veg',
#   'kuttu',
#   'parotta'],
#  ['much', 'ecpected'],
#  ['good',
#   'place',
#   'team',
#   'lunch',
#   'hygiene',
#   'good',
#   'ambience',
#   'hospital',
#   'friendly',
#   'serve',
#   'staff',
#   'sahil',
#   'sakhil',
#   'overall',
#   'great',
#   'timemaximum',
#   'number',
#   'option',
#   'starter',
#   'desert'],
#  ['disappoint',
#   'experience',
#   'ever',
#   'order',
#   'vegetable',
#   'biryani',
#   'midnight',
#   'hour',
#   'restaurant',
#   'delivery',
#   'swiggy',
#   'quick',
#   'swift',
#   'surprise',
#   'receive',
#   'biryani',
#   'rice',
#   'absolute',
#   'vegetable',
#   'masala',
#   'bland',
#   'taste',
#   'understand',
#   'restaurant',
#   'cheat',
#   'customer',
#   'stock',
#   'would',
#   'recommend',
#   'anyone',
#   'trust',
#   'restaurant'],
#  ['place',
#   'earlier',
#   'didnt',
#   'like',
#   'ambiencethis',
#   'time',
#   'order',
#   'mini',
#   'chicken',
#   'biryani',
#   'food',
#   'panda',
#   '66',
#   'r',
#   'totally',
#   'worth',
#   'money',
#   'spenttaste',
#   'good',
#   'chicken',
#   'would',
#   'bite',
#   'tenderit',
#   'lot',
#   'well',
#   'famous',
#   'neighbourtaste',
#   'goodambience',
#   'bad'],
#  ['receive',
#   'pizza',
#   'bake',
#   'properlyraw',
#   'inside',
#   'instead',
#   'pasta',
#   'order',
#   'initially',
#   'didn’t',
#   'like',
#   'pizza',
#   'accept',
#   'order',
#   'run',
#   'short',
#   'stock'],
#  ['superb',
#   'service',
#   'awesome',
#   'food',
#   'nice',
#   'place',
#   'friend',
#   'family',
#   'good',
#   'ambience',
#   'lovely',
#   'music',
#   'friendly',
#   'staff',
#   'creamy',
#   'mushroom',
#   'good'],
#  ['bad',
#   'service',
#   'ever',
#   'experience',
#   'order',
#   'item',
#   'one',
#   'take',
#   'responsibility',
#   'bring',
#   'stay',
#   'corner',
#   'chit',
#   'chat',
#   'lady',
#   'say',
#   'ur',
#   'service',
#   'bad',
#   'smile',
#   'sarcastic',
#   'way',
#   'go',
#   'replace',
#   'item',
#   '20min',
#   'wait',
#   'item',
#   'even',
#   'bowl',
#   'sweet',
#   'bring',
#   'half',
#   'hour',
#   '5',
#   'last',
#   'feed',
#   'service',
#   'think',
#   'sweet',
#   'find',
#   'cockroache',
#   'bowl',
#   'call',
#   'lady',
#   'waiter',
#   'respond',
#   'go',
#   'kitchen',
#   'call',
#   'person',
#   'ranjith',
#   'take',
#   'bowl',
#   'go',
#   'inside',
#   'kitchen',
#   'come',
#   'back',
#   'say',
#   'sorry',
#   'offer',
#   '5',
#   'ice',
#   'cream',
#   'around',
#   '30',
#   'people',
#   'say',
#   'come',
#   'evng',
#   'next',
#   'day',
#   'dont',
#   'know',
#   'think',
#   'customer',
#   'basically',
#   'look',
#   'like',
#   'decent',
#   'star',
#   'hotel',
#   'people',
#   'service',
#   'like',
#   'irani',
#   'cafe',
#   'least',
#   'cafe',
#   'order',
#   'get',
#   'fast',
#   'else',
#   'inform',
#   'u',
#   'late',
#   'heard',
#   'lot',
#   'jonathan',
#   'kitchen',
#   'food',
#   'absolutely',
#   'good',
#   'people',
#   'behaviour',
#   'neatness',
#   'bad',
#   'kindly',
#   'find',
#   'attachment',
#   'thank',
#   'never',
#   'visit',
#   'u'],
#  ['chocolate',
#   'quality',
#   'bad',
#   'consider',
#   'high',
#   'price',
#   'taste',
#   'similar',
#   'equivalent',
#   '30',
#   'rupee',
#   'milkshake',
#   'get',
#   'carton',
#   'lodge',
#   'recommend',
#   'anyone'],
#  ['staff',
#   'polite',
#   'food',
#   'really',
#   'extraordinary',
#   'hesitation',
#   'would',
#   'love',
#   'visit',
#   'place',
#   'n',
#   'number',
#   'time',
#   'would',
#   'suggest',
#   'everyone',
#   'visit'],
#  ['north',
#   'miss',
#   'chat',
#   'place',
#   'must',
#   'visit',
#   'chat',
#   'lover',
#   'tastiest',
#   'samosa',
#   'chat',
#   'bhel',
#   'puri',
#   'pani',
#   'puri',
#   'amaze'],
#  ['stone', 'food'],
#  ['gobindpassionate',
#   'servingpolite',
#   'naturestrict',
#   'duty',
#   'really',
#   'nice',
#   'experience',
#   'everything',
#   'suoerb',
#   'thanks',
#   '3bs',
#   'give',
#   'u',
#   'nice',
#   'din'],
#  ['outlet',
#   'bad',
#   'ever',
#   'see',
#   'cockroach',
#   'table',
#   'food',
#   'quality',
#   'bad',
#   'one',
#   'take',
#   'order',
#   'time',
#   'please',
#   'go',
#   'outlet',
#   'dont',
#   'ever',
#   'try',
#   'outlet'],
#  ['food',
#   'really',
#   'great',
#   'go',
#   'office',
#   'colleague',
#   'staff',
#   'much',
#   'supportive',
#   'make',
#   'u',
#   'wait',
#   'long',
#   'time',
#   'per',
#   'food',
#   'taste',
#   'great',
#   'paneer',
#   'lababdar',
#   'great',
#   'paneer',
#   'chunk',
#   'soft',
#   'curry',
#   'flavour',
#   'butter',
#   'naan',
#   'order',
#   'must',
#   'say',
#   'much',
#   'butter',
#   'taste',
#   'great',
#   'special',
#   'chicken',
#   'biriyani',
#   'colleague',
#   'order',
#   'great',
#   'also',
#   'staff',
#   'little',
#   'edge',
#   'food',
#   'really',
#   'great'],
#  ['visited',
#   'place',
#   'friday',
#   'first',
#   'would',
#   'like',
#   'compliment',
#   'dj',
#   'zain',
#   'sabri',
#   'playing',
#   'whatever',
#   'song',
#   'i’ve',
#   'request',
#   'food',
#   'good',
#   'ambiance',
#   'perfect',
#   'friend',
#   'we’ll',
#   'surely',
#   'come',
#   'back'],
#  ['service',
#   'good',
#   'plate',
#   'cleanly',
#   'wash',
#   'serve',
#   'properly',
#   'look',
#   'picture',
#   'bad',
#   'spoon',
#   'bowl'],
#  ['visit',
#   'place',
#   'awesome',
#   'bakery',
#   'option',
#   'try',
#   'pasta',
#   'toffee',
#   'apple',
#   'doughnut',
#   'though',
#   'pasta',
#   'mark',
#   'apple',
#   'doughnut',
#   'balance',
#   'ambiance',
#   'pretty',
#   'cool'],
#  ['food',
#   'ambience',
#   'service',
#   'everything',
#   'greatgobi',
#   'manchurian',
#   'awesome',
#   'tandoori',
#   'chicken',
#   'good',
#   'would',
#   'highly',
#   'recommend',
#   'visit',
#   'place'],
#  ['sunday',
#   'afternoon',
#   'visit',
#   'place',
#   'bunch',
#   'foodie',
#   'experience',
#   'new',
#   'menu',
#   'add',
#   'recently',
#   'small',
#   'outlet',
#   'around',
#   '15',
#   'people',
#   'accommodate',
#   'timecoming',
#   'delicacyclassic',
#   'shake',
#   'poppy',
#   'cherry',
#   'merry',
#   'cherry',
#   'two',
#   'shake',
#   'try',
#   'poppy',
#   'cherry',
#   'like',
#   'butter',
#   'popcorn',
#   'shake',
#   'decent',
#   'merry',
#   'cherry',
#   'simply',
#   'outstanding',
#   'love',
#   'itpremium',
#   'shake',
#   'cruncy',
#   'blue',
#   'berry',
#   'caramel',
#   'brownie',
#   'favorites',
#   'must',
#   'try',
#   'shake',
#   'placeexclusive',
#   'shake',
#   'coffee',
#   'hazlenut',
#   'cookie',
#   'feast',
#   'delicious',
#   'cheesecake',
#   'decent',
#   'nothing',
#   'greatcrushers',
#   'orange',
#   'bright',
#   'poppy',
#   'corn',
#   'mint',
#   'cucumber',
#   'crusher',
#   'try',
#   'okfries',
#   'peri',
#   'peri',
#   'fry',
#   'cajun',
#   'spice',
#   'fry',
#   'really',
#   'outstanding',
#   'love',
#   'itpotato',
#   'wedge',
#   'one',
#   'decent',
#   'jamaican',
#   'dipsoverall',
#   'new',
#   'menu',
#   'quite',
#   'hit',
#   'amazing',
#   'exclusive',
#   'premium',
#   'shake',
#   'heavy',
#   'pocket',
#   'tasty',
#   'time',
#   'invite',
#   'management',
#   'new',
#   'menu',
#   'session',
#   'visit',
#   'sure',
#   'future',
#   'taste',
#   'shake',
#   'delicaciesmust',
#   'try',
#   'dish',
#   '🌟merry',
#   'cherrycaramel',
#   'browniecookie',
#   'feastperi',
#   'peri',
#   'fry'],
#  ['starter',
#   'good',
#   'main',
#   'course',
#   'lack',
#   'salt',
#   'bit',
#   'lemon',
#   'juice',
#   'order',
#   'palak',
#   'paneer',
#   'ive',
#   'food',
#   'amazing',
#   'time',
#   'slight',
#   'disappointment',
#   'last',
#   'time',
#   'chicken',
#   'tikka',
#   'really',
#   'amazing'],
#  ['order',
#   'tandoori',
#   'chicken',
#   'starter',
#   'thats',
#   'tasty',
#   'light',
#   'butter',
#   'naan',
#   'mutton',
#   'masala',
#   'main',
#   'course',
#   'order',
#   'chicken',
#   'biryani',
#   'egg',
#   'mutton',
#   'biryani',
#   'tasty',
#   'light',
#   'mutton',
#   'piecs',
#   'cook',
#   'perfection'],
#  ['best',
#   'shawarma',
#   'serve',
#   'reasonable',
#   'price',
#   'mayonnaise',
#   'simply',
#   'awesomerumali',
#   'shawarma',
#   'withwithout',
#   'salad',
#   'best',
#   'one',
#   'till',
#   'date'],
#  ['poor',
#   'quality',
#   'quantity',
#   'food',
#   'nice',
#   'packing',
#   'nice',
#   'food',
#   'taste',
#   'full',
#   'feeling',
#   'sad',
#   'order',
#   'food',
#   'restaurant'],
#  ['good'],
#  ['ali',
#   'muntu',
#   'fantastic',
#   'service',
#   'food',
#   'service',
#   'excellent',
#   'table',
#   'service',
#   'good',
#   'hygenic',
#   'atmosphere',
#   'welcome',
#   'warm',
#   'staff',
#   'friendly',
#   'supportive',
#   'take',
#   'good',
#   'care',
#   'u'],
#  ['send',
#   'wrong',
#   'order',
#   'order',
#   'mutton',
#   'biryani',
#   'send',
#   'chicken',
#   'biryani',
#   'app',
#   'bad',
#   'app',
#   'cant',
#   'even',
#   'get',
#   'touch',
#   'customer',
#   'care'],
#  ['good',
#   'place',
#   'good',
#   'north',
#   'indian',
#   'meal',
#   'many',
#   'option',
#   'food',
#   'taste',
#   'really',
#   'good',
#   'order',
#   'masala',
#   'papad',
#   'dal',
#   'makhni',
#   'paneer',
#   'lababdar',
#   'along',
#   'bread',
#   'service',
#   'quick',
#   'wait',
#   'fair',
#   'share',
#   'get',
#   'food',
#   'paneer',
#   'lababdar',
#   'tasty',
#   'dal',
#   'makhnipaneer',
#   'lababdar',
#   '485dal',
#   'makhni',
#   '445ambience',
#   '35overall',
#   '45'],
#  ['finally',
#   'momo',
#   'joint',
#   'consistent',
#   'taste',
#   'quality',
#   'really',
#   'love',
#   'variety',
#   'momos',
#   'offer',
#   'good',
#   'price',
#   'great',
#   'taste',
#   'delightful',
#   'thumb',
#   '👍'],
#  ['avg',
#   'biryani',
#   'lot',
#   'well',
#   'order',
#   'tadoori',
#   'chicken',
#   'well',
#   'ordinary',
#   'well',
#   'much',
#   'good',
#   'place',
#   'go',
#   'place'],
#  ['oilly', 'inspite', 'say', 'put', 'less', 'oil', 'good', 'quantity'],
#  ['one',
#   'order',
#   'chicken',
#   'wrap',
#   'would',
#   '5',
#   'star',
#   'amount',
#   'salt',
#   'add',
#   'unbearable',
#   'something',
#   'also',
#   'rice',
#   'dish',
#   'fine'],
#  ['food',
#   'quality',
#   'bad',
#   'literally',
#   'vomitted',
#   'food',
#   'atetoo',
#   'oilywe',
#   'can’t',
#   'eati',
#   'don’t',
#   'suggest',
#   'restaurant',
#   'didnt',
#   'expect',
#   'santhosh',
#   'dhaba',
#   'branch'],
#  ['go',
#   'frio',
#   'bistro',
#   'lazy',
#   'sunday',
#   'even',
#   'it’s',
#   'easy',
#   'find',
#   'cozy',
#   'place',
#   'right',
#   'main',
#   'road',
#   'portion',
#   'make',
#   'one',
#   'person',
#   'fill',
#   'alfredo',
#   'pasta',
#   'hand',
#   'one',
#   'best',
#   'pasta',
#   'i’ve',
#   'city',
#   'starter',
#   'good',
#   'filling',
#   'mocktails',
#   'fun',
#   'tasty',
#   'drinkswhat',
#   'tomato',
#   'olive',
#   'bruschetta',
#   'highly',
#   'recommend',
#   'chilli',
#   'cheese',
#   'roll',
#   'spinach',
#   'corn',
#   'cheese',
#   'ravioli',
#   'artichoke',
#   'baby',
#   'corn',
#   'la',
#   'plancha',
#   'cranberry',
#   'kiss',
#   'highly',
#   'recommended',
#   'mojitoambience',
#   '45food',
#   '455cost',
#   'efficiency',
#   '45',
#   'could',
#   'high',
#   'zomato',
#   'gold',
#   'saviour'],
#  ['loved',
#   'place',
#   'attractive',
#   'best',
#   'view',
#   'top',
#   'service',
#   'good',
#   'enjoy',
#   'tasty',
#   'food',
#   'customize',
#   'way',
#   'want',
#   'minor',
#   'drawback',
#   'find',
#   'parking'],
#  ['restaurant',
#   'always',
#   'rely',
#   'restaurant',
#   'use',
#   'default',
#   'choice',
#   'whenever',
#   'want',
#   'eat',
#   'dont',
#   'feel',
#   'like',
#   'search',
#   'anew',
#   'place',
#   'great',
#   'quality',
#   'food',
#   'good',
#   'service',
#   'haleem',
#   'nice',
#   'though',
#   'bit',
#   'sweet',
#   'taste',
#   'suppose',
#   'mildly',
#   'sweet',
#   'anyway',
#   'fault',
#   'location',
#   'also',
#   'perfect'],
#  ['good', 'frappe', 'thanks', 'good', 'experience'],
#  ['nice',
#   'place',
#   'good',
#   'foodambience',
#   'pretty',
#   'dark',
#   'good',
#   'dinner',
#   'give',
#   'feel',
#   'dinner',
#   'even',
#   'lunch',
#   'feel',
#   'nicefood',
#   'order',
#   'kurmure',
#   'cheese',
#   'kebab',
#   'kadhai',
#   'paneer',
#   'kashmiri',
#   'garlic',
#   'naan',
#   'deliciousmeccai',
#   'kebab',
#   'spicy',
#   'okayish',
#   'may',
#   'order',
#   'big',
#   'big',
#   'fan',
#   'spicy',
#   'combo',
#   'corn',
#   'kebab'],
#  ['receive',
#   'wrong',
#   'orderi',
#   'try',
#   'contact',
#   'restaurant',
#   'didn’t',
#   'receive',
#   'callthis',
#   'bad',
#   'experience',
#   'ever',
#   'order',
#   'online'],
#  ['omg',
#   'hyderabad',
#   'vacay',
#   'happen',
#   'famous',
#   'bakeryfallen',
#   'love',
#   'hybd',
#   'bakeryhd',
#   'vlvte',
#   'cake',
#   'n',
#   'cheese',
#   'cakeeach',
#   'n',
#   'evry',
#   'cake',
#   'stole',
#   'heartbig',
#   'love',
#   'me🤗🤗🤗😋😋🍰🍰🍰🍰😋'],
#  ['good'],
#  ['ahmed',
#   'serve',
#   'u',
#   'polite',
#   'cooperative',
#   'staffamazing',
#   'food',
#   'ambienceveg',
#   'gilaffi',
#   'kabab',
#   'lasgna',
#   'must',
#   'tryloved',
#   'overall',
#   'experience'],
#  ['ambience',
#   'good',
#   'food',
#   'need',
#   'improvement',
#   'aspect',
#   'service',
#   'bit',
#   'slow',
#   'toothis',
#   'place',
#   'overhyped',
#   'food',
#   'quality',
#   'improvedit',
#   'pricey',
#   'definitely',
#   'value',
#   'money'],
#  ['rahamath',
#   'bhahadur',
#   'one',
#   'best',
#   'serve',
#   'dish',
#   'food',
#   'simply',
#   'amazing',
#   'point',
#   'definitely',
#   'visit',
#   'happy',
#   'face'],
#  ['nice', 'service'],
#  ['want',
#   'go',
#   'place',
#   'since',
#   'long',
#   'time',
#   'one',
#   'old',
#   'cafe',
#   'go',
#   'lunch',
#   'time',
#   'along',
#   'nri',
#   'friend',
#   'sit',
#   'corner',
#   'loved',
#   'view',
#   'look',
#   'vintage',
#   'beautiful',
#   'ambience',
#   'come',
#   'food',
#   'order',
#   'lemon',
#   'corainder',
#   'soup',
#   'nacho',
#   'fry',
#   'rice',
#   'taste',
#   'good'],
#  ['mathura',
#   'vila',
#   'renowned',
#   'speciality',
#   'time',
#   'try',
#   'offer',
#   'chinese',
#   'food',
#   'restaurant',
#   'order',
#   'veg',
#   'noodle',
#   'manchurian',
#   'gravythe',
#   'taste',
#   'come',
#   'fine',
#   'wasnt',
#   'happy',
#   'manchurian',
#   'lack',
#   'veggie'],
#  ['follow',
#   'instagram',
#   'page',
#   'journeywithfoodiesspourhouse7',
#   'spacious',
#   'rooftop',
#   'bar',
#   'offer',
#   'amaze',
#   'ambiance',
#   'like',
#   'birdeye',
#   'point',
#   'view',
#   'live',
#   'music',
#   'screening',
#   'comfortable',
#   'seating',
#   'arrangement',
#   'accord',
#   'convenience',
#   'service',
#   'prompt',
#   'staff',
#   'polite',
#   'friendlycoming',
#   'mocktailswe',
#   'try',
#   'virgin',
#   'mojito',
#   'virgin',
#   'colada',
#   'sweet',
#   'sunrise',
#   'virgin',
#   'mojito',
#   'sweet',
#   'sunrise',
#   'really',
#   'refresh',
#   'virgin',
#   'colada',
#   'okayappetizersmurgh',
#   'lasooni',
#   'kali',
#   'mirch',
#   'tikkatandoori',
#   'chicken',
#   'black',
#   'pepper',
#   'cardamom',
#   'garam',
#   'masala',
#   'chicken',
#   'skewer',
#   'soak',
#   'marinade',
#   'cook',
#   'tandoor',
#   'spice',
#   'give',
#   'rustic',
#   'feel',
#   'super',
#   'delicious',
#   'highly',
#   'recommendcrispy',
#   'chilli',
#   'fishthe',
#   'flavour',
#   'texture',
#   'crispy',
#   'chilli',
#   'fish',
#   'really',
#   'amazingclassic',
#   'chicken',
#   'spring',
#   'rollsthe',
#   'roll',
#   'fill',
#   'chicken',
#   'full',
#   'veggie',
#   'deeply',
#   'fry',
#   'taste',
#   'amaze',
#   'crispness',
#   'point',
#   'serve',
#   'sweet',
#   'spicy',
#   'sauce',
#   'dip',
#   'must',
#   'try',
#   'outgreat',
#   'nawabi',
#   'pizzathe',
#   'pizza',
#   'load',
#   'cheese',
#   'chicken',
#   'veggie',
#   'taste',
#   'great',
#   'presentation',
#   'could',
#   'bettertangadi',
#   'kababchicken',
#   'drumstick',
#   'marinate',
#   'aromatic',
#   'indian',
#   'spice',
#   'grill',
#   'perfection',
#   'really',
#   'amazing',
#   'term',
#   'tasteonion',
#   'ringsthese',
#   'easy',
#   'onion',
#   'ring',
#   'double',
#   'dip',
#   'batter',
#   'season',
#   'perfection',
#   'crust',
#   'crisp',
#   'onion',
#   'tender',
#   'sweet',
#   'serve',
#   'hot',
#   'spicy',
#   'saucemain',
#   'course7h',
#   'biryanithe',
#   'biryani',
#   'enclose',
#   'egg',
#   'omelette',
#   'chicken',
#   'tender',
#   'basmati',
#   'rice',
#   'fluffy',
#   'amazing',
#   'tastepestorice',
#   'chicken',
#   'stroganoffpesto',
#   'green',
#   'rice',
#   'flavour',
#   'jarred',
#   'pesto',
#   'top',
#   'fresh',
#   'herb',
#   'chicken',
#   'stroganoff',
#   'make',
#   'chicken',
#   'breast',
#   'smother',
#   'sour',
#   'cream',
#   'stroganoff',
#   'sauce',
#   'really',
#   'deliciousdessertwe',
#   'try',
#   'brownie',
#   'vanilla',
#   'icecream',
#   'top',
#   'hershey’s',
#   'syrup',
#   'treat',
#   'taste',
#   'budsoverall',
#   'experience',
#   'pourhouse7',
#   'really',
#   'amazing',
#   'thanks',
#   'staff',
#   'offer',
#   'great',
#   'hospitality'],
#  ['karachi',
#   'bakery',
#   'various',
#   'item',
#   'cake',
#   'biscuit',
#   'snack',
#   'several',
#   'variety',
#   'biscuit',
#   'available',
#   'include',
#   'famous',
#   'osmania',
#   'biscuit',
#   'cake',
#   'pastry',
#   'also',
#   'good',
#   'taste',
#   'quality'],
#  ['chicken',
#   'biryani',
#   'taste',
#   'awesome',
#   'al',
#   'saba',
#   'restaurant',
#   'think',
#   'dont',
#   'like',
#   'maintenance',
#   'bad',
#   'otherwise',
#   'really',
#   'tasty',
#   'worthy'],
#  ['lunch',
#   'friendsgot',
#   'amaizing',
#   'experience',
#   'indigrillfood',
#   'awesome',
#   'best',
#   'barbeque',
#   'grill',
#   'city',
#   'server',
#   'sahilsakilbala',
#   'courteous',
#   'polite'],
#  ['randomly',
#   'sudden',
#   'decision',
#   'take',
#   'couple',
#   'colleague',
#   'place',
#   'weekday',
#   'lunch',
#   'unsure',
#   'choice',
#   'saw',
#   'people',
#   'sit',
#   'open',
#   'hut',
#   'din',
#   'heat',
#   'wave',
#   'moment',
#   'open',
#   'seem',
#   'like',
#   'kitchen',
#   'door',
#   'thrown',
#   'aback',
#   'see',
#   '100',
#   'people',
#   'belt',
#   'south',
#   'indian',
#   'meat',
#   'man',
#   'place',
#   'oasis',
#   'puppalguda',
#   'desertwe',
#   'mutton',
#   'lover',
#   'order',
#   'nalli',
#   'starter',
#   'charcoal',
#   'mutton',
#   'chop',
#   'look',
#   'crowd',
#   'mentally',
#   'prepare',
#   'go',
#   'back',
#   'office',
#   'evening',
#   'post',
#   'chai',
#   'break',
#   'waiter',
#   'promptly',
#   'bring',
#   'food',
#   'le',
#   '10',
#   'minute',
#   'scalpel',
#   'like',
#   'tool',
#   'operate',
#   'nalli',
#   'eye',
#   'shine',
#   'nalli',
#   'disappoint',
#   'u',
#   'dug',
#   'chop',
#   'hour',
#   'spend',
#   'drool',
#   'pork',
#   'rib',
#   'youtube',
#   'redeem',
#   'mutton',
#   'chop',
#   'deed',
#   'meat',
#   'wasnt',
#   'slimy',
#   'fatty',
#   'kind',
#   'melt',
#   'bone',
#   'perfectly',
#   'grill',
#   'meat',
#   'willing',
#   'separate',
#   'rib',
#   'mild',
#   'effort',
#   'already',
#   'dream',
#   'another',
#   'plate',
#   'decide',
#   'best',
#   'interest',
#   'belly',
#   'come',
#   'main',
#   'course',
#   'rotis',
#   'mamasam',
#   'pachadi',
#   'chicken',
#   'biriyani',
#   'first',
#   'bite',
#   'mamasam',
#   'pachadi',
#   'throw',
#   'chair',
#   'back',
#   '5',
#   'foot',
#   'decide',
#   'ask',
#   'waiter',
#   'pack',
#   'biriyani',
#   'order',
#   'another',
#   'round',
#   'rotis',
#   'honour',
#   'pachadi',
#   'person',
#   'consciously',
#   'keep',
#   'away',
#   'gongura',
#   'chutney',
#   'one',
#   'clearly',
#   'gongura',
#   'perfectly',
#   'sour',
#   'bit',
#   'sour',
#   'wouldnt',
#   'care',
#   'write',
#   'review',
#   'meat',
#   'invisible',
#   'spot',
#   'narrow',
#   'bone',
#   'pachadi',
#   'even',
#   'know',
#   'mutton',
#   'mystically',
#   'omni',
#   'present',
#   'meat',
#   'guess',
#   'would',
#   'call',
#   'divine',
#   'foodamen'],
#  ['worst', 'pack'],
#  ['nice',
#   'placegood',
#   'ambiancesuper',
#   'friendly',
#   'helpful',
#   'staff',
#   'nilok',
#   'da',
#   'best',
#   'staff',
#   'among',
#   'allhe',
#   'understand',
#   'need',
#   'suggest',
#   'food',
#   'accordingly'],
#  ['awesome',
#   'experience',
#   'taste',
#   'fantastic',
#   'service',
#   'wonderful',
#   'give',
#   'nandan',
#   'varun',
#   'guy',
#   'friendly',
#   'good',
#   'manner',
#   'way',
#   'talk',
#   'polite',
#   'courteous'],
#  ['absolutely',
#   'loved',
#   'place',
#   'highly',
#   'recommendedfood',
#   'delicious',
#   'exotic',
#   'hygienic',
#   'try',
#   'lobster',
#   'prawn',
#   'red',
#   'wine',
#   'want',
#   'try',
#   'crab',
#   'kind',
#   'wine',
#   'available',
#   'maybe',
#   'keep',
#   'menu',
#   'item',
#   'stock',
#   'may',
#   'get',
#   'item',
#   'list',
#   '1010ambiance',
#   'beautiful',
#   'live',
#   'music',
#   'great',
#   'lightening',
#   'party',
#   'nice',
#   'dinner',
#   '810service',
#   'satisfy',
#   'prepare',
#   'food',
#   'like',
#   'would',
#   'like',
#   'ask',
#   'instruction',
#   'waiter',
#   'polite',
#   'nice',
#   'serve',
#   'u',
#   'cake',
#   'go',
#   'birthday',
#   'celebration',
#   'pastry',
#   'still',
#   'nice',
#   'gesture',
#   '810'],
#  ['order',
#   'veg',
#   'singapore',
#   'rice',
#   'work',
#   'really',
#   'awesome',
#   'respect',
#   'quality',
#   'quantity',
#   'would',
#   'signature',
#   'dish',
#   'hungry',
#   'order',
#   'base',
#   'review',
#   'give',
#   'friend',
#   'really',
#   'worth'],
#  ['order', 'fast'],
#  ['authentic',
#   'taste',
#   'north',
#   'east',
#   'indian',
#   'delicacy',
#   'one',
#   'find',
#   'mouthwatering',
#   'dish',
#   'good',
#   'place',
#   'good',
#   'location',
#   'quantity',
#   'food',
#   'per',
#   'dish',
#   'serve',
#   'little',
#   'small'],
#  ['one',
#   'best',
#   'shawarma',
#   'joint',
#   'hyderabadthe',
#   'quantity',
#   'enough',
#   'satisfy',
#   'one',
#   'crave',
#   'shawarma',
#   'chicken',
#   'tender',
#   'juicy',
#   'mayonnaise',
#   'work',
#   'like',
#   'charm',
#   'chickenmust',
#   'try',
#   'special',
#   'rumali',
#   'shawarmaif',
#   'north',
#   'indian',
#   'love',
#   'shawarma',
#   'place',
#   'chicken',
#   'lollipop',
#   'also',
#   'one',
#   'speciality'],
#  ['presentation',
#   '5',
#   'starsquatity',
#   '5',
#   'starsprice',
#   '5',
#   'starstaste',
#   '3',
#   'starsfreshness',
#   '2',
#   'starswill',
#   'try',
#   'come',
#   'conclusion'],
#  ['little', 'bland', 'like'],
#  ['seat',
#   'table',
#   'center',
#   'area',
#   'crook',
#   'couch',
#   'comfortable',
#   'big',
#   'group',
#   'fooddrinks',
#   'par',
#   'place',
#   'area',
#   'nothing',
#   'special',
#   'light',
#   'almost',
#   'perfectly',
#   'dim',
#   'environmentambiance',
#   'really',
#   'nice',
#   'lady',
#   'karaoke',
#   'dj',
#   'night',
#   'service',
#   'could',
#   'lot',
#   'good',
#   'put',
#   'food',
#   'table',
#   'leave',
#   'behard',
#   'miss',
#   'place',
#   'beside',
#   'gachibowli',
#   'flyover',
#   'enough',
#   'park',
#   'space',
#   'place',
#   'remain',
#   'kinda',
#   'empty',
#   'weekdaysservice',
#   '255price',
#   '35ambiance',
#   '355'],
#  ['extremely',
#   'pathetic',
#   'third',
#   'class',
#   'service',
#   'cleanliness',
#   'ordere',
#   'simple',
#   'noodle',
#   'wait',
#   'one',
#   'hour',
#   'waiter',
#   'come',
#   'tell',
#   'forgot',
#   'never',
#   'ever',
#   'go',
#   'recommend',
#   'go',
#   'place',
#   'close'],
#  ['food',
#   'good',
#   'come',
#   'team',
#   'lunch',
#   'starter',
#   'get',
#   '4',
#   'item',
#   'taste',
#   'starter',
#   'good',
#   'place',
#   'good',
#   'veg',
#   'non',
#   'veg',
#   'lover',
#   'lover',
#   'sweets',
#   'two',
#   'ice',
#   'cream',
#   'flavour',
#   'rasgulla',
#   'kaddu',
#   'ka',
#   'kheer',
#   'etc',
#   'eat',
#   'kaddu',
#   'ka',
#   'kheer'],
#  ['veg', 'biriyani', 'okaynot', 'good'],
#  ['awesome',
#   'place',
#   'enjoy',
#   'chinese',
#   'look',
#   'ordinary',
#   'outside',
#   'interior',
#   'restaurant',
#   'classy',
#   'ambience',
#   'really',
#   'good',
#   'amaze',
#   'surprising',
#   'part',
#   'restaurant',
#   'food',
#   'amaze',
#   'food',
#   '100',
#   'must',
#   'go',
#   'place',
#   'foodie',
#   'price',
#   'match',
#   'quantityquality',
#   'doesnt',
#   'leave',
#   'hole',
#   'pocket',
#   'set',
#   'restaurant',
#   'mile',
#   'apart',
#   'comparison',
#   'similar',
#   'level',
#   'chinese',
#   'restaurantthis',
#   'restaurant',
#   'definitely',
#   'one',
#   'top',
#   'favourites',
#   'consider',
#   'chinese'],
#  ['low', 'quality'],
#  ['definitely',
#   'enjoy',
#   'food',
#   '100veg',
#   'rating',
#   'food',
#   '355',
#   'service',
#   '355',
#   'ambiance',
#   '355',
#   'biryani',
#   '355',
#   'kaju',
#   'biryani',
#   'good',
#   'cantry'],
#  ['amaze',
#   'range',
#   'ice',
#   'cream',
#   'great',
#   'sense',
#   'pack',
#   'doesn’t',
#   'melt',
#   'soon',
#   'since',
#   'put',
#   'frozen',
#   'nitrogen',
#   'cube',
#   'lovely',
#   'idea',
#   'great',
#   'sense',
#   'packing',
#   'compare',
#   'ice',
#   'cream',
#   'delivery',
#   'must',
#   'order',
#   'guy',
#   'order',
#   'lot',
#   'time'],
#  ['ordered',
#   'nice',
#   'dinner',
#   'two',
#   'grill',
#   'price',
#   'mediocre',
#   'place',
#   'order',
#   'late',
#   'night',
#   'via',
#   'uber',
#   'eats',
#   'follow',
#   'experienceservice',
#   'parcel',
#   'come',
#   'around',
#   '10',
#   'minute',
#   'later',
#   'estimate',
#   'delivery',
#   'boy',
#   'call',
#   'outside',
#   'society',
#   '35presentationpackaging',
#   'usual',
#   'packing',
#   'nothing',
#   'extraordinary',
#   'anything',
#   'bad',
#   '35food',
#   'food',
#   'fine',
#   'really',
#   'kill',
#   'appetite',
#   'amount',
#   'chilli',
#   'add',
#   'tried',
#   'followingpaneer',
#   'pulao',
#   'nice',
#   'quantity',
#   'sufficient',
#   'two',
#   'average',
#   'number',
#   'paneer',
#   'piece',
#   'taste',
#   'quite',
#   'yum',
#   'masala',
#   'ample',
#   'inside',
#   'spicy',
#   'kill',
#   'essence',
#   '355gobi',
#   '65',
#   'good',
#   'quantity',
#   'two',
#   'taste',
#   'like',
#   'typical',
#   'fry',
#   'gobi',
#   'nothing',
#   'extraordinary',
#   'usual',
#   '35will',
#   'order',
#   'decrease',
#   'spice',
#   'level',
#   'despite',
#   'mention',
#   'clearly',
#   'extra',
#   'special',
#   'instruction',
#   'supremely',
#   'spicy',
#   'make',
#   'fill',
#   'stomach',
#   'water'],
#  ['name',
#   'suggest',
#   'wing',
#   'mouth',
#   'water',
#   'really',
#   'enjoy',
#   'taste',
#   'tenderjuicy',
#   'freshly',
#   'prepared',
#   'chicken',
#   'lot',
#   'variety',
#   'sauce',
#   'different',
#   'kind',
#   'wing',
#   'always',
#   'push',
#   'order',
#   'restaurantquantity',
#   'combos',
#   'huge',
#   'heard',
#   'ambience',
#   'good',
#   'look',
#   'forward',
#   'come',
#   'dine'],
#  ['usually',
#   'dont',
#   'write',
#   'review',
#   'perhaps',
#   'first',
#   'one',
#   'probably',
#   'guess',
#   'level',
#   'frustration',
#   'place',
#   'one',
#   'wordsmall',
#   'deplorable',
#   'cold',
#   'food',
#   'poor',
#   'service',
#   'sum',
#   'quite',
#   'surprising',
#   'part',
#   'elite',
#   'chainactually',
#   'shock',
#   'spare',
#   'moneygo',
#   'well',
#   'placenot',
#   'one'],
#  ['kindly',
#   'try',
#   'put',
#   'stuff',
#   'waffle',
#   'order',
#   'two',
#   'bread',
#   'hence',
#   'couldnt',
#   'eat',
#   'ice',
#   'cream',
#   'waffle',
#   'melt',
#   'kindly',
#   'remove',
#   'online',
#   'unable',
#   'deliver',
#   'dry',
#   'ice',
#   'banana',
#   'caramel',
#   'waffle',
#   'dry',
#   'expect',
#   'good',
#   'quality',
#   'next',
#   'order',
#   'thanks',
#   'lot'],
#  ['good'],
#  ['food',
#   'good',
#   'leaking',
#   'plate',
#   'quantity',
#   'le',
#   'compare',
#   'expected',
#   'rice',
#   'well',
#   'thali',
#   'miss'],
#  ['pizza',
#   'deliver',
#   '2',
#   'hour',
#   'place',
#   'order',
#   'cold',
#   'inspite',
#   'raise',
#   'complain',
#   '34',
#   'time',
#   'receive',
#   'customer',
#   'support',
#   'wasnt',
#   'even',
#   'contact',
#   'supervisor',
#   'needless',
#   'say',
#   'wasnt',
#   'even',
#   'reimburse',
#   'late',
#   'delivery',
#   'cold',
#   'pizza'],
#  ['bad',
#   'shawarma',
#   'ever',
#   'order',
#   'three',
#   'time',
#   'every',
#   'single',
#   'time',
#   'get',
#   'yukkiest',
#   'shawarma',
#   'ever',
#   'mayonnaise',
#   'chicken',
#   'smell',
#   'like',
#   'hell',
#   'uncooked',
#   'rumali',
#   'roti',
#   'never',
#   'go',
#   'eat',
#   'place'],
#  ['ive',
#   'call',
#   'veg',
#   'well',
#   'chicken',
#   'fried',
#   'maggie',
#   'hundred',
#   'time',
#   'delicious',
#   'different',
#   'taste',
#   'maggie',
#   'place',
#   'around',
#   'however',
#   '2',
#   'day',
#   'back',
#   'order',
#   'food',
#   'taste',
#   'peculiar',
#   'smell',
#   'never',
#   'take',
#   'two',
#   'bite',
#   'leave',
#   'bite',
#   'create',
#   'havoc',
#   'entire',
#   'night',
#   'leave',
#   'bad',
#   'stomach',
#   'pain',
#   'ive',
#   'never',
#   'experience',
#   'honestly',
#   'didnt',
#   'even',
#   'expect',
#   'would',
#   'create',
#   'mess',
#   'people',
#   'always',
#   'say',
#   'avoid',
#   'street',
#   'side',
#   'food',
#   'close',
#   'vehicle',
#   'place',
#   'never',
#   'disappoint',
#   'except',
#   'particular',
#   'order',
#   'guess',
#   'never',
#   'risk',
#   'stomach',
#   'go',
#   'miss',
#   'maggie',
#   'much',
#   '😷'],
#  ['good'],
#  ['biriyani',
#   'taste',
#   'nice',
#   'must',
#   'try',
#   'ulavacharu',
#   'flavour',
#   'nothing',
#   'say',
#   'ambience',
#   'nothing',
#   'much',
#   'say',
#   'overall',
#   'service'],
#  ['best',
#   'place',
#   'cake',
#   'n',
#   'bake',
#   'foodthe',
#   'best',
#   'bread',
#   'super',
#   'thin',
#   'delicious',
#   'cheeze',
#   'pizza',
#   'pasta',
#   'available',
#   'dont',
#   'miss',
#   'old',
#   'style',
#   'dark',
#   'chocolate',
#   'cake',
#   '🍰'],
#  ['cutlery', 'seal', 'box', 'poor', 'packing'],
#  ['labonel',
#   'old',
#   'favourite',
#   'many',
#   'year',
#   'cooky',
#   'brownie',
#   'always',
#   'high',
#   'demand',
#   'anyone',
#   'visit',
#   'town',
#   'take',
#   'away',
#   'however',
#   'would',
#   'highly',
#   'recommend',
#   'try',
#   'make',
#   'order',
#   'menu',
#   'item',
#   'fudge',
#   'cake',
#   'chocolate',
#   'pie',
#   'chocolate',
#   'roulade'],
#  ['food', 'taste', 'differentdidnt', 'feel', 'eat', 'kfc', 'chicken'],
#  ['average',
#   'restaurantfood',
#   'goodmost',
#   'people',
#   'go',
#   'buffetthey',
#   'serve',
#   'cheap',
#   'welcome',
#   'drinkwhich',
#   'infect',
#   'throatthats'],
#  ['buffet',
#   'good',
#   'rather',
#   'ala',
#   'carte',
#   '1010',
#   'decor',
#   'ambience',
#   'service',
#   'quick',
#   'beautiful',
#   'view',
#   'hyderabad',
#   'must',
#   'visit',
#   'place'],
#  ['beautifulpeaceful',
#   'relax',
#   'staff',
#   'outstanding',
#   'restaurant',
#   'exceptional',
#   'along',
#   'host',
#   'server',
#   'must',
#   'visit',
#   'place'],
#  ['heard',
#   'lot',
#   'place',
#   'many',
#   'suggest',
#   'it’s',
#   'must',
#   'try',
#   'finally',
#   'tried',
#   'lit',
#   'interest',
#   'la',
#   'carte',
#   'menu',
#   'food',
#   'different',
#   'cuisinesthe',
#   'ambiance',
#   'good',
#   'pretty',
#   'much',
#   'similar',
#   'fine',
#   'dining',
#   'restaurant',
#   'except',
#   'wobble',
#   'chairsi',
#   'find',
#   'service',
#   'quite',
#   'quick',
#   'clean',
#   'food',
#   'bring',
#   'table',
#   'right',
# ...
#   'deliver',
#   'food',
#   '130',
#   'hour',
#   'latewhen',
#   'call',
#   'ask',
#   'replied',
#   'lot',
#   'ordersthis',
#   'farewe',
#   'wait',
#   'almost',
#   '90mins',
#   '20mins',
#   'delivery'],
#  ['order',
#   'double',
#   'margherita',
#   'pizza',
#   'white',
#   'sauce',
#   'pasta',
#   'texture',
#   'white',
#   'sauce',
#   'clumpy',
#   'pasta',
#   'still',
#   'hot',
#   'pizza',
#   'fine',
#   'taste',
#   'wise',
#   'cant',
#   'call',
#   'margherita',
#   'pizza',
#   'strand',
#   'shred',
#   'basil',
#   'dry',
#   'sachet',
#   'oregano',
#   'season',
#   'expire',
#   '3',
#   'month',
#   'ago',
#   'june',
#   'open',
#   'sachet',
#   'lot',
#   'clump',
#   'okay',
#   'give',
#   'season',
#   'dont',
#   'sending',
#   'expire',
#   'stuff',
#   'completely',
#   'unacceptable',
#   'delivery',
#   'pack',
#   'good',
#   'wish',
#   'pay',
#   'attention',
#   'food'],
#  ['great',
#   'place',
#   'amaze',
#   'ambience',
#   'perfect',
#   'location',
#   'excellent',
#   'service',
#   'sarvesharam',
#   'good',
#   'beer',
#   'especially',
#   'house',
#   'brew',
#   'great',
#   'food',
#   'must',
#   'visit',
#   'place',
#   'music',
#   'always',
#   'good'],
#  ['glass',
#   'onion',
#   '🍚🍚',
#   'place',
#   'trend',
#   'zomato',
#   'ever',
#   'since',
#   'openned',
#   'gain',
#   'popularity',
#   'short',
#   'span',
#   'time',
#   'eye',
#   'finally',
#   'felt',
#   'delighted',
#   'visiting',
#   'saturday',
#   'night🌙ambience⛲',
#   'oh',
#   'wobby',
#   '😍',
#   'beautify',
#   'ambience',
#   'indooroutdoor',
#   'sit',
#   'option',
#   'spread',
#   'accross',
#   'huge',
#   'space',
#   'situate',
#   'inside',
#   'boulder',
#   'hill',
#   'hence',
#   'area',
#   'peaceful',
#   'calm',
#   'need',
#   'reservation',
#   'outdoors',
#   'place',
#   'mostly',
#   'fill',
#   'peopleservice',
#   'food',
#   'super',
#   'fast',
#   'service',
#   'sumptous',
#   'food',
#   'periodfrom',
#   'kung',
#   'pow',
#   'chicken',
#   'cheese',
#   'base',
#   'brocolli',
#   'nachos',
#   'chicken',
#   'chettinad',
#   'everything',
#   'lovely',
#   'go',
#   'ask',
#   'more😌yay',
#   'nay',
#   '👍👍👍'],
#  ['go',
#   'team',
#   'out',
#   'restaurant',
#   'caters',
#   'mass',
#   'corporate',
#   'sector',
#   'great',
#   'spread',
#   'buffet',
#   'starter',
#   'either',
#   'spicy',
#   'undercooked',
#   'main',
#   'course',
#   'spread',
#   'average',
#   'fresh',
#   'jalebi',
#   'good',
#   'addition',
#   'otherwise',
#   'average',
#   'dessert',
#   'spread'],
#  ['american',
#   'wild',
#   'wing',
#   'affordable',
#   'version',
#   'bdubs',
#   'mainly',
#   'focus',
#   'wing',
#   'fry',
#   'burger',
#   'touch',
#   'desi',
#   'dish',
#   'welli',
#   'wife',
#   'dinner',
#   'delightful',
#   'time',
#   'love',
#   'chicken',
#   'wing',
#   'various',
#   'sauce',
#   'offer',
#   'amaze',
#   'try',
#   'pattaya',
#   'thai',
#   'texas',
#   'bbq',
#   'mexican',
#   'jerk',
#   'original',
#   'hot',
#   'amazon',
#   'wild',
#   'like',
#   'bbq',
#   'original',
#   'hot',
#   'exceptional',
#   'move',
#   'chicken',
#   'nugget',
#   'chicken',
#   'fried',
#   'burger',
#   'grill',
#   'chicken',
#   'salad',
#   'nugget',
#   'amaze',
#   'crispy',
#   'soft',
#   'burger',
#   'salad',
#   'delicious',
#   'wellwe',
#   'soft',
#   'drink',
#   'mocktails',
#   'namely',
#   'lemonade',
#   'mango',
#   'pretty',
#   'good',
#   'improvedservice',
#   'great',
#   'well',
#   'take',
#   'care',
#   'mr',
#   'srinivas',
#   'branch',
#   'manager',
#   'ambience',
#   'okay',
#   'need',
#   'work',
#   'upon',
#   'bit',
#   'upcoming',
#   'fastfood',
#   'jointoverall',
#   'excellent',
#   'place',
#   'chicken',
#   'wing',
#   'lover',
#   'moderate',
#   'price',
#   'range'],
#  ['follow',
#   'u',
#   'instagram',
#   'foodieshotshyd',
#   'tilt',
#   'european',
#   'bar',
#   'unique',
#   'bar',
#   'hyderabad',
#   'serve',
#   'variety',
#   'import',
#   'beer',
#   'newly',
#   'open',
#   'microbrewery',
#   'struggle',
#   'serve',
#   'good',
#   'quality',
#   'beer',
#   'consistently',
#   'tilt',
#   'fill',
#   'vacuum',
#   'interesting',
#   'note',
#   'import',
#   'beer',
#   'brew',
#   'trappist',
#   'monk',
#   'also',
#   'apparently',
#   'good',
#   'quality',
#   'ingredient',
#   'go',
#   'brew',
#   'beer',
#   'ensure',
#   'contribute',
#   'dreadful',
#   'beer',
#   'belly',
#   'taste',
#   'almost',
#   'beer',
#   'thanks',
#   'sampler',
#   'set',
#   'contain',
#   'belgian',
#   'kreik',
#   'chamborlette',
#   'la',
#   'trappe',
#   'witte',
#   'dubbel',
#   'erdinger',
#   'weisbier',
#   'erdinger',
#   'dunkel',
#   'schuimzuiper',
#   'like',
#   'dubbel',
#   'la',
#   'trappe',
#   'witte',
#   'erdinger',
#   'dunkel',
#   'also',
#   'serve',
#   'variety',
#   'mocktails',
#   'favorite',
#   'one',
#   'mint',
#   'mango',
#   'glowtheir',
#   'food',
#   'menu',
#   'compliment',
#   'beer',
#   'well',
#   'appetizer',
#   'like',
#   'cajun',
#   'spice',
#   'grill',
#   'chicken',
#   'zesty',
#   'chicken',
#   'wing',
#   'cilantro',
#   'grilled',
#   'fish',
#   'cheese',
#   'broccoli',
#   'guess',
#   'spicy',
#   'fry',
#   'idly',
#   'expect',
#   'spicy',
#   'fry',
#   'idly',
#   'menu',
#   'taste',
#   'understood',
#   'popular',
#   'appetizer',
#   'love',
#   'chicken',
#   'wing',
#   'juicy',
#   'bestin',
#   'main',
#   'course',
#   'serve',
#   'grilled',
#   'fish',
#   'veggie',
#   'lamb',
#   'chop',
#   'rice',
#   'french',
#   'fry',
#   'mains',
#   'great',
#   'dessert',
#   'blueberry',
#   'cheese',
#   'cake',
#   'choco',
#   'lava',
#   'cake',
#   'cheese',
#   'cake',
#   'fail',
#   'impress',
#   'u',
#   'choco',
#   'lava',
#   'cake',
#   'finger',
#   'lick',
#   'good',
#   'end',
#   'wonderful',
#   'lunch',
#   'session',
#   'shot',
#   'smeets',
#   'waffle',
#   'jenever',
#   'brilliant',
#   'sweet',
#   'taste',
#   'belgian',
#   'waffle',
#   'must',
#   'try',
#   'overall',
#   'tilt',
#   'european',
#   'bar',
#   'great',
#   'place',
#   'hangout',
#   'friends',
#   'great',
#   'imported',
#   'beer',
#   'delicious',
#   'food'],
#  ['lovely',
#   'time',
#   '3bs',
#   'thank',
#   'govind',
#   'make',
#   'special',
#   'patienly',
#   'customize',
#   'food',
#   'accord',
#   'taste',
#   'casual',
#   'occasion',
#   'make',
#   'memorable'],
#  ['actually',
#   'struggle',
#   '3',
#   '4',
#   'place',
#   'drink',
#   'good',
#   'buffet',
#   'doesnt',
#   'last',
#   'totally',
#   'classy',
#   'atmosphere',
#   'buffet',
#   'area',
#   'good',
#   'vibe',
#   'first',
#   'floor',
#   'brewery',
#   'one',
#   'best',
#   'little',
#   'costly',
#   'caution',
#   'stag',
#   'majority',
#   'time',
#   'wont',
#   'allow',
#   'u',
#   'ground',
#   'floor',
#   'evening',
#   'kind',
#   'suck',
#   'though',
#   'finally',
#   'value',
#   'money',
#   'date',
#   'team',
#   'else',
#   'little',
#   'expensive'],
#  ['place',
#   'fun',
#   'awesome',
#   'ambience',
#   'food',
#   'great',
#   'staff',
#   'interactive',
#   'drink',
#   'ok',
#   'expensive',
#   'overall',
#   'nice',
#   'place',
#   'chill',
#   'fun'],
#  ['generally',
#   'get',
#   'food',
#   'deliver',
#   'place',
#   'kung',
#   'pao',
#   'chicken',
#   'rice',
#   'bowl',
#   'favourite',
#   'place',
#   'serve',
#   'veg',
#   'fry',
#   'rice',
#   'spicy',
#   'daily',
#   'like',
#   'also',
#   'taste',
#   'fish',
#   'n',
#   'chip',
#   'place',
#   'menu',
#   'bit',
#   'pricy',
#   'taste',
#   'good'],
#  ['one',
#   'best',
#   'biryani',
#   'ever',
#   'had❤️chicken',
#   'piece',
#   'r',
#   'cook',
#   'perfection',
#   'blend',
#   'spice',
#   'delicious',
#   '👌must',
#   'visit',
#   'hyderabadi',
#   'cuisine'],
#  ['good'],
#  ['almost',
#   'like',
#   'want',
#   'get',
#   'food',
#   'wait',
#   '15',
#   'hour',
#   'food',
#   'get',
#   'way',
#   'order',
#   'bbq',
#   'veg',
#   'pizza',
#   'bake',
#   'corn',
#   'onion',
#   'bread',
#   'small',
#   'portion',
#   'size',
#   'make',
#   'worth',
#   'order',
#   'veg',
#   'lasagna',
#   'cancel',
#   'end',
#   'due',
#   'come',
#   'reason'],
#  ['sausage', 'shawrma', 'roll'],
#  ['hello',
#   'guy',
#   'honest',
#   'review',
#   'visit',
#   'yesterday7th',
#   'dec',
#   'heard',
#   'lot',
#   'restaurant',
#   'mixed',
#   'experience',
#   'enter',
#   'place',
#   'definitely',
#   'feel',
#   'bad',
#   'smell',
#   'inside',
#   'really',
#   'disgust',
#   'order',
#   'chicken',
#   'lollipop',
#   'smoke',
#   'pork',
#   'bosam',
#   'ramyun',
#   'noodle',
#   'food',
#   'awesome',
#   'except',
#   'bosam',
#   'didnt',
#   'like',
#   'taste',
#   'want',
#   'try',
#   'northeast',
#   'food',
#   'surely',
#   'give',
#   'try'],
#  ['waste',
#   'restauranti',
#   'order',
#   'special',
#   'chicken',
#   'shawarma',
#   'cheese',
#   'get',
#   'rotten',
#   'smell',
#   'happen',
#   'several',
#   'time',
#   'even',
#   'zomato',
#   'people',
#   'unable',
#   'help',
#   '🖕🖕🖕'],
#  ['extremely',
#   'bad',
#   'food',
#   'gachibowli',
#   'location',
#   'order',
#   'food',
#   'party',
#   'deliver',
#   'stale',
#   'food',
#   'despite',
#   'inform',
#   'order',
#   'food',
#   'kid',
#   'one',
#   'child',
#   'get',
#   'food',
#   'poison',
#   'aswelli',
#   'inform',
#   'management',
#   'even',
#   'get',
#   'back',
#   'check',
#   'kid',
#   'fell',
#   'sick',
#   'doingextremely',
#   'poor',
#   'food',
#   'quality',
#   'hospitality',
#   'thoroughly',
#   'embarrass',
#   'front',
#   'guest',
#   'regret',
#   'choose',
#   'restaurant',
#   'event'],
#  ['daawat',
#   'khaas',
#   'murgh',
#   'musallamsinkanderi',
#   'raanssabz',
#   'kebab',
#   'platterthese',
#   'item',
#   'best',
#   'ate',
#   'collegues',
#   'everyone',
#   'try',
#   'these😀'],
#  ['tempteys', 'well', 'every', 'milkshake', 'brand'],
#  ['regular',
#   'customer',
#   'reason',
#   'tasty',
#   'food',
#   'good',
#   'variety',
#   'dish',
#   'service',
#   'provide',
#   'ratul',
#   'highly',
#   'recommend',
#   'place'],
#  ['heard',
#   'lot',
#   'place',
#   'amaze',
#   'paranthas',
#   'decide',
#   'try',
#   'order',
#   'combo',
#   'punjabi',
#   'aloo',
#   'parantha',
#   'cheese',
#   'corn',
#   'parantha',
#   'love',
#   'food',
#   'packaging',
#   'chutney',
#   'dahi',
#   'pickle',
#   'come',
#   'separate',
#   'container',
#   'parantha',
#   'pack',
#   'well',
#   'pip',
#   'hotcoming',
#   'taste',
#   'would',
#   'say',
#   'loved',
#   'aloo',
#   'parantha',
#   'excellent',
#   'corn',
#   'cheese',
#   'parantha',
#   'good',
#   'couldnt',
#   'find',
#   'cheese',
#   'parantha',
#   'guess',
#   'would',
#   'never',
#   'order',
#   'corn',
#   'cheese',
#   'parantha',
#   'would',
#   'love',
#   'try',
#   'paranthas',
#   'triptify',
#   'wpuld',
#   'definitely',
#   'recommend',
#   'others',
#   'try',
#   'place'],
#  ['restaurant',
#   'provide',
#   'good',
#   'food',
#   'happy',
#   'ask',
#   'double',
#   'masala',
#   'didnt',
#   'give',
#   'food',
#   'upset',
#   'time'],
#  ['good'],
#  ['restaurant',
#   'ambience',
#   'nicefood',
#   'tasty',
#   'cost',
#   'reasonablestaff',
#   'politethey',
#   'offer',
#   '45',
#   'different',
#   'variety',
#   'beer',
#   'taste',
#   'amaze'],
#  ['burger', 'quality', 'decrease'],
#  ['food',
#   'quality',
#   'average',
#   'except',
#   'kaju',
#   'paneer',
#   'curry',
#   'averageand',
#   'order',
#   'extra',
#   'onion',
#   'lemonthere',
#   'onion',
#   'lemon',
#   'packplease',
#   'make',
#   'sure',
#   'food',
#   'quality',
#   'good'],
#  ['good',
#   'place',
#   'hangout',
#   'chill',
#   'terrace',
#   'seating',
#   'also',
#   'good',
#   'ambiance',
#   'ok',
#   'book',
#   'table',
#   'via',
#   'dineoutindia',
#   'rather',
#   'drink',
#   'food',
#   'good',
#   'hereand',
#   'frame1',
#   'spicy',
#   'chicken',
#   'table',
#   'spicy',
#   'taste',
#   'excellent',
#   'pizza',
#   'order',
#   'chicken',
#   'keema',
#   'pizza',
#   'also',
#   'good',
#   'thin',
#   'crest',
#   'cheese',
#   'also',
#   'good',
#   'mustang',
#   'terrace',
#   'loungethe',
#   'disappointment',
#   'drink'],
#  ['would',
#   'like',
#   'start',
#   'worth',
#   'itwent',
#   'dinner',
#   'buffeti',
#   'love',
#   'spread',
#   'asian',
#   'indian',
#   'dish',
#   'buffeton',
#   'top',
#   'excellent',
#   'service',
#   'polite',
#   'staff',
#   'restaurantwhat',
#   'else',
#   'could',
#   'u',
#   'asksimply',
#   'amaze',
#   'friday',
#   'night'],
#  ['really',
#   'impressed',
#   'ambience',
#   'simple',
#   'menu',
#   'option',
#   'available',
#   'say',
#   'rightly',
#   'simplicity',
#   'attracts',
#   'able',
#   'spend',
#   'quality',
#   'time',
#   'even',
#   'start',
#   'coffee',
#   'end',
#   'desert',
#   'definitely',
#   'plan',
#   'visit'],
#  ['chaat',
#   'restaurant',
#   'offer',
#   'amaze',
#   'never',
#   'ate',
#   'delicious',
#   'sevpuri',
#   'ever',
#   'hyderabad',
#   'amazing',
#   'taste',
#   'satisfy',
#   'quantity',
#   'chaat',
#   'lover',
#   'must',
#   'try',
#   '❤️'],
#  ['ordered',
#   'fish',
#   'fry',
#   'good',
#   'zesty',
#   'chicken',
#   'wing',
#   'good',
#   'crispy',
#   'corn',
#   'tasty',
#   'dont',
#   'remember',
#   'name',
#   'chicken',
#   'item',
#   'best'],
#  ['food',
#   '55ambience45service45drinks35must',
#   'try',
#   'place',
#   'arekung',
#   'pao',
#   'fishschezwan',
#   'chickengarlic',
#   'chickenbhutan',
#   'chickenpepper',
#   'fish'],
#  ['taste',
#   'really',
#   'good',
#   'non',
#   'veg',
#   'starter',
#   'veg',
#   'paneer',
#   'starter',
#   'awesome',
#   'butter',
#   'non',
#   'soft',
#   'goodnice',
#   'place',
#   'visitgood',
#   'staff',
#   'polite'],
#  ['nil'],
#  ['bit',
#   'expensive',
#   'taste',
#   'wise',
#   'it’s',
#   'fabulous',
#   'trust',
#   'order',
#   'hot',
#   'chocolate',
#   'pasta',
#   'coffees',
#   'food',
#   '🥘',
#   'delicious',
#   'look',
#   'forward',
#   'visit',
#   'thanks'],
#  ['quantity',
#   'le',
#   'last',
#   'two',
#   'month',
#   'give',
#   '3',
#   'big',
#   'order',
#   'time',
#   'quality',
#   'quantity',
#   'good',
#   'base',
#   'order',
#   'today',
#   'disappoint',
#   'go',
#   'order'],
#  ['rating',
#   '355although',
#   'little',
#   'resemblance',
#   'lebanese',
#   'shawarma',
#   'wrap',
#   'rumali',
#   'roti',
#   'shawarma',
#   'taste',
#   'good',
#   'wrap',
#   'good',
#   'quantity',
#   'chicken',
#   'stuffing',
#   'sauce',
#   'good',
#   'chicken',
#   'quite',
#   'spicy',
#   'look',
#   'healthy',
#   'food',
#   'shawarma',
#   'isnt',
#   'call',
#   'fast',
#   'delivery'],
#  ['many',
#   'issue',
#   'start',
#   '1',
#   'valet',
#   'parking',
#   'quote',
#   '2',
#   'everything',
#   'serve',
#   'plate',
#   'chill',
#   'mean',
#   'it3',
#   'nothing',
#   'plan',
#   'like',
#   'placement',
#   'food',
#   'day',
#   'day',
#   'kitchen4',
#   'contrary',
#   'icecream',
#   'already',
#   'melt',
#   'taste',
#   'good',
#   'serve',
#   'properly',
#   'wouldve',
#   'definitely',
#   'deserve',
#   '4hope',
#   'thing',
#   'take',
#   'proper',
#   'care'],
#  ['ordered',
#   'signature',
#   'chicken',
#   'wing',
#   'zomato',
#   '1xfrench',
#   'fry',
#   '6x',
#   'chicken',
#   'wing',
#   'one',
#   'coke350mlquantity',
#   'satisfactorypackaging',
#   'food',
#   'good',
#   'really',
#   'like',
#   'package',
#   'coke',
#   'still',
#   'bit',
#   'cold',
#   'arrive',
#   'may',
#   'call',
#   'excessive',
#   'packaging',
#   'howeverthe',
#   'fry',
#   'warm',
#   'well',
#   'salt',
#   'crispy',
#   'could',
#   'fault',
#   'delivery',
#   'upset',
#   '1',
#   'restaurant',
#   'zomato',
#   'far',
#   'manage',
#   'deliver',
#   'crispy',
#   'fry',
#   'consistentlythe',
#   'wing',
#   'cover',
#   'brown',
#   'gravy',
#   'expect',
#   'crispy',
#   'wing',
#   'like',
#   'photograph',
#   'wing',
#   'certainly',
#   'bad',
#   'enjoy',
#   'muchi',
#   'would',
#   'recommend',
#   'order',
#   'restaurant',
#   'try'],
#  ['ambience',
#   'decent',
#   'go',
#   'lady',
#   'night',
#   'tad',
#   'bit',
#   'crowded',
#   'understandable',
#   'music',
#   'good',
#   'downside',
#   'whole',
#   'thing',
#   'person',
#   'give',
#   'drink',
#   'counter',
#   'downright',
#   'ignore',
#   'u',
#   'actually',
#   'become',
#   'little',
#   'uncomfortable',
#   'right',
#   'front',
#   'wave',
#   'hand',
#   'drunk',
#   'ask',
#   'first',
#   'drink',
#   'night',
#   'hand',
#   'drink',
#   'everyone',
#   'else',
#   'except',
#   'u',
#   'look',
#   'like',
#   'something',
#   'againts',
#   'u'],
#  ['food',
#   'quality',
#   'quantity',
#   'mark',
#   'family',
#   'pack',
#   'chicken',
#   'biriyani',
#   'come',
#   '430',
#   'r',
#   'contains',
#   '2',
#   'pretty',
#   'small',
#   'piece',
#   'rice',
#   'relatively',
#   'less',
#   'raita',
#   'salan',
#   'give',
#   'worth',
#   'moneyquality',
#   'also',
#   'good',
#   'didnt',
#   'feel',
#   'anything',
#   'great',
#   'bad',
#   'place',
#   'order',
#   'food',
#   'sorry',
#   'however',
#   'thats',
#   'reality',
#   'thanks'],
#  ['nice', 'taste', 'chutney', 'quantity', 'need', 'improve'],
#  ['irrespective',
#   'high',
#   'reputation',
#   'authentic',
#   'andhra',
#   'food',
#   'restaurant',
#   'highly',
#   'disappointedtasted',
#   'kheema',
#   'biryani',
#   'upto',
#   'markthe',
#   'service',
#   'slow',
#   'ambiance',
#   'ok'],
#  ['one',
#   'best',
#   'buffet',
#   'ever',
#   'start',
#   'food',
#   'much',
#   'variety',
#   'every',
#   'thing',
#   'super',
#   'yumm',
#   'lip',
#   'smack',
#   'main',
#   'course',
#   'item',
#   'dal',
#   'makhani',
#   'simply',
#   'bestthe',
#   'best',
#   'part',
#   'desserts',
#   'much',
#   'variety',
#   'cant',
#   'greed',
#   'satisfymust',
#   'try',
#   'place',
#   'though',
#   'little',
#   'high',
#   'pocketand',
#   'service',
#   'also',
#   'good',
#   'love',
#   'it😊'],
#  ['delicious', 'momos', 'match', 'expectation'],
#  ['place',
#   'always',
#   'exceed',
#   'expectation',
#   'friendly',
#   'staff',
#   'customise',
#   'order',
#   'finger',
#   'lick',
#   'good',
#   'food',
#   'course',
#   'need',
#   'second',
#   'stomach',
#   'dessert'],
#  ...]

# %%
word2vec_model = Word2Vec(Word2vec_train_data,
                 vector_size=100,
                 workers=8,
                 min_count=5)

# %%
maxLen = 200
tokenizer = Tokenizer(num_words=10000, oov_token="<oov>")
tokenizer.fit_on_texts(x_train)

# %%
words_to_index = tokenizer.word_index
vocab_len = len(words_to_index)

# %%
x_train_w2v = tokenizer.texts_to_sequences(x_train)
x_test_w2v = tokenizer.texts_to_sequences(x_test)

x_test_w2v = pad_sequences(x_test_w2v, maxlen=maxLen, padding='post')
x_train_w2v = pad_sequences(x_train_w2v, maxlen=maxLen, padding='post')

# %%
x_train_w2v.shape
# Out:
# (7952, 200)

# %%
emb_matrix = np.zeros((vocab_len, Embedding_dimensions))

for word, token in tokenizer.word_index.items():
    if word2vec_model.wv.__contains__(word):
        emb_matrix[token] = word2vec_model.wv.__getitem__(word)

# %%
emb_matrix.shape
# Out:
# (21184, 100)

# %%
embedding_layer = Embedding(input_dim=vocab_len, output_dim=Embedding_dimensions, input_length=maxLen, weights = [emb_matrix], trainable=False)

# %%
model = lstm_model((maxLen,))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200)]             0
#
#  embedding (Embedding)       (None, 200, 100)          2118400
#
#  lstm_1 (LSTM)               (None, 200, 128)          117248
#
#  dropout (Dropout)           (None, 200, 128)          0
#
#  lstm_2 (LSTM)               (None, 200, 128)          131584
#
#  dropout_1 (Dropout)         (None, 200, 128)          0
#
#  lstm_3 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 2,498,945
# Trainable params: 380,545
# Non-trainable params: 2,118,400
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(x_train_w2v, y_train, epochs=15, validation_data = (x_test_w2v, y_test), callbacks=callbacks)
# Out:
# Epoch 1/15
# 249/249 [==============================] - 11s 34ms/step - loss: 0.6637 - accuracy: 0.6295 - val_loss: 0.6534 - val_accuracy: 0.6434
# Epoch 2/15
# 249/249 [==============================] - 8s 32ms/step - loss: 0.6568 - accuracy: 0.6320 - val_loss: 0.6498 - val_accuracy: 0.6434
# Epoch 3/15
# 249/249 [==============================] - 8s 33ms/step - loss: 0.6576 - accuracy: 0.6319 - val_loss: 0.6524 - val_accuracy: 0.6434
# Epoch 4/15
# 249/249 [==============================] - 10s 40ms/step - loss: 0.6575 - accuracy: 0.6320 - val_loss: 0.6505 - val_accuracy: 0.6434
# Epoch 5/15
# 249/249 [==============================] - 13s 53ms/step - loss: 0.6572 - accuracy: 0.6320 - val_loss: 0.6497 - val_accuracy: 0.6434
# Epoch 6/15
# 249/249 [==============================] - 12s 50ms/step - loss: 0.6570 - accuracy: 0.6322 - val_loss: 0.6518 - val_accuracy: 0.6434

# %% [markdown]
# ### Doc2Vec

# %%
documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(data['tokens'])]

# %%
doc2vec_model = Doc2Vec(documents, vector_size=50, window=3, min_count=1, workers=4)

# %%
data['tokens'][0]
# Out:
# "['ambience', 'good', 'food', 'quite', 'good', 'saturday', 'lunch', 'cost', 'effective', 'good', 'place', 'sate', 'brunch', 'one', 'also', 'chill', 'friend', 'parentswaiter', 'soumen', 'das', 'really', 'courteous', 'helpful']"

# %%
data['tokens'] = [simple_preprocess(line, deacc=True) for line in data['Clean_Review']]

# %%
x_train, x_test, y_train, y_test = train_test_split(pd.DataFrame(data['token']), pd.DataFrame(data['Sentiment']), test_size=0.2, random_state=42)

# %%
x_train_d2v = []
for index, row in x_train.iterrows():
    model_vector = doc2vec_model.infer_vector(row['token'])
    x_train_d2v.append(model_vector)

# %%
x_test_d2v = []
for index, row in x_test.iterrows():
    model_vector = doc2vec_model.infer_vector(row['token'])
    x_test_d2v.append(model_vector)

# %%
x_train_d2v = np.array(x_train_d2v)
x_test_d2v = np.array(x_test_d2v)

# %%
x_train_d2v.shape
# Out:
# (7952, 50)

# %%
data
# Out:
#                                                  Review  Rating  \
# 0     The ambience was good, food was quite good . h...     5.0
# 1     Ambience is too good for a pleasant evening. S...     5.0
# 2     A must try.. great food great ambience. Thnx f...     5.0
# 3     Soumen das and Arun was a great guy. Only beca...     5.0
# 4     Food is good.we ordered Kodi drumsticks and ba...     5.0
# ...                                                 ...     ...
# 9935  Madhumathi Mahajan Well to start with nice cou...     3.0
# 9936  This place has never disappointed us.. The foo...     4.5
# 9937  Bad rating is mainly because of "Chicken Bone ...     1.5
# 9938  I personally love and prefer Chinese Food. Had...     4.0
# 9939  Checked in here to try some delicious chinese ...     3.5
#
#                                            Clean_Review  Sentiment  \
# 0     ambience good food quite good  saturday lunch ...          1
# 1     ambience good pleasant even service prompt foo...          1
# 2     must try great food great ambience thnx servic...          1
# 3     soumen das arun great guy behavior sincerety g...          1
# 4     food goodwe order kodi drumstick basket mutton...          1
# ...                                                 ...        ...
# 9935  madhumathi mahajan well start nice courteous s...          0
# 9936  place never disappoint u food courteous staff ...          1
# 9937  bad rating mainly chicken bone find veg food a...          0
# 9938  personally love prefer chinese food couple tim...          1
# 9939  check try delicious chinese food see nonveg lu...          1
#
#                                                  tokens
# 0     ['ambience', 'good', 'food', 'quite', 'good', ...
# 1     ['ambience', 'good', 'pleasant', 'even', 'serv...
# 2     ['must', 'try', 'great', 'food', 'great', 'amb...
# 3     ['soumen', 'das', 'arun', 'great', 'guy', 'beh...
# 4     ['food', 'goodwe', 'order', 'kodi', 'drumstick...
# ...                                                 ...
# 9935  ['madhumathi', 'mahajan', 'well', 'start', 'ni...
# 9936  ['place', 'never', 'disappoint', 'u', 'food', ...
# 9937  ['bad', 'rating', 'mainly', 'chicken', 'bone',...
# 9938  ['personally', 'love', 'prefer', 'chinese', 'f...
# 9939  ['check', 'try', 'delicious', 'chinese', 'food...
#
# [9940 rows x 5 columns]

# %%
clf_d2v = RandomForestClassifier()
clf_d2v.fit(x_train_d2v, y_train)
# Out:
# c:\Users\Anantha\miniconda3\envs\gpukeras\lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
y_pred_d2v = clf_d2v.predict(x_test_d2v)
accuracy_d2v = accuracy_score(y_test, y_pred_d2v)
print("Accuracy using d2v:", accuracy_d2v)
# Out:
# Accuracy using d2v: 0.6373239436619719
